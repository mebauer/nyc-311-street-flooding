# %% [markdown]
# # Analyzing NYC's 311 Street Flooding Complaints from 2010 to 2020
# ## *Data Inspection*
#
# Mark Bauer

# %% [markdown]
# # Goal
# In this notebook, we inspect and preview our data before we begin analysis. Specifically, I attempt to inspect the following items:
#
# - the shape of the data
# - number of null/na values in the dataset
# - identify columns and data types
# - descriptive or summary statistics
# - correlation of columns
#
# # Main Python Libraries
# [pandas](https://pandas.pydata.org/) is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool, built on top of the Python programming language.
#
# [Seaborn](https://seaborn.pydata.org/index.html) is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.

# %% [markdown]
# # Datasets
#
# ## 311 Service Requests from 2010 to Present
# Website: https://data.cityofnewyork.us/Social-Services/311-Service-Requests-from-2010-to-Present/erm2-nwe9
#
# 311's data dictionary can be found in the data folder.
#
#
#
# ![311](../images/nyc-311-screenshot.png)

# %% [markdown]
# Table of Contents
# =================
#
#    * [1. Importing Libraries](#1-Importing-Libraries)
#
#
#    * [2. Loading Data](#2-Loading-Data)
#
#
#    * [3. Data Inspection](#3-Data-Inspection)
#        * [3.1 Basic Data Inspection](#31-Basic-Data-Inspection)
#        * [3.2 Calculating Summary Statistics](#32-Calculating-Summary-Statistics)
#        * [3.3 Identifying Null/NA Values](#33-Identifying-Null/NA-Values)
#        * [3.4 Inspecting Items In Each Column](#34-Inspecting-Items-In-Each-Column)

# %% [markdown]
# # 1. Importing Libraries

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['savefig.facecolor'] = 'white'
# %matplotlib inline

# %% [markdown]
# Printing versions of Python modules and packages with **watermark** - the IPython magic extension.

# %%
# %load_ext watermark
# Out:
# The watermark extension is already loaded. To reload it, use:
#   %reload_ext watermark

# %%
# %watermark -v -p numpy,pandas,seaborn
# Out:
# CPython 3.7.1
# IPython 7.20.0
#
# numpy 1.19.2
# pandas 1.2.1
# seaborn 0.11.1

# %% [markdown]
# Documention for installing watermark: https://github.com/rasbt/watermark

# %% [markdown]
# # 2. Loading Data

# %%
# list items in data folder
# %ls ../data-raw/
# Out:
# README.md                           raw_street_flooding_complaints.csv
# data-dictionaries/                  raw_streets_clipped.json

# %%
# read data as a dataframe
flooding_311 = pd.read_csv('../data-raw/raw_street_flooding_complaints.csv', 
                           low_memory=False)

# previewing first five rows in data
flooding_311.head()
# Out:
#    unique_key             created_date              closed_date agency  \
# 0    35467474  2017-02-11T14:49:00.000  2017-02-17T11:19:00.000    DEP
# 1    35473543  2017-02-12T19:03:00.000  2017-02-12T19:03:00.000    DEP
# 2    35475940  2017-02-12T14:38:00.000  2017-02-12T15:20:00.000    DEP
# 3    35478538  2017-02-13T13:11:00.000  2017-02-15T09:30:00.000    DEP
# 4    35479396  2017-02-13T07:26:00.000  2017-02-13T08:10:00.000    DEP
#
#                               agency_name complaint_type  \
# 0  Department of Environmental Protection          Sewer
# 1  Department of Environmental Protection          Sewer
# 2  Department of Environmental Protection          Sewer
# 3  Department of Environmental Protection          Sewer
# 4  Department of Environmental Protection          Sewer
#
#              descriptor  incident_zip       incident_address  \
# 0  Street Flooding (SJ)      10312.00     152 BARCLAY AVENUE
# 1  Street Flooding (SJ)      11231.00                    NaN
# 2  Street Flooding (SJ)      10465.00    659 CLARENCE AVENUE
# 3  Street Flooding (SJ)      11210.00                    NaN
# 4  Street Flooding (SJ)      10466.00  1635 EAST  233 STREET
#
#         street_name  ... park_facility_name   park_borough latitude longitude  \
# 0    BARCLAY AVENUE  ...        Unspecified  STATEN ISLAND    40.54    -74.17
# 1               NaN  ...        Unspecified       BROOKLYN    40.68    -73.99
# 2   CLARENCE AVENUE  ...        Unspecified          BRONX    40.83    -73.81
# 3               NaN  ...        Unspecified       BROOKLYN    40.62    -73.94
# 4  EAST  233 STREET  ...        Unspecified          BRONX    40.89    -73.83
#
#                                             location intersection_street_1  \
# 0  {'latitude': '40.53905963837945', 'longitude':...                   NaN
# 1  {'latitude': '40.67694549612395', 'longitude':...              3 STREET
# 2  {'latitude': '40.82869324687791', 'longitude':...                   NaN
# 3  {'latitude': '40.61981574824473', 'longitude':...        EAST 32 STREET
# 4  {'latitude': '40.88818786782963', 'longitude':...                   NaN
#
#   intersection_street_2 location_type due_date  landmark
# 0                   NaN           NaN      NaN       NaN
# 1           BOND STREET           NaN      NaN       NaN
# 2                   NaN           NaN      NaN       NaN
# 3              AVENUE M           NaN      NaN       NaN
# 4                   NaN           NaN      NaN       NaN
#
# [5 rows x 34 columns]

# %%
# previewing the last five rows of our dataframe
flooding_311.tail()
# Out:
#        unique_key             created_date              closed_date agency  \
# 27423    35457500  2017-02-10T15:39:00.000  2017-02-13T08:45:00.000    DEP
# 27424    35458891  2017-02-10T09:17:00.000  2017-02-11T10:10:00.000    DEP
# 27425    35461648  2017-02-10T09:58:00.000  2017-02-10T14:00:00.000    DEP
# 27426    35461654  2017-02-10T13:20:00.000  2017-02-12T10:55:00.000    DEP
# 27427    35461860  2017-02-10T16:55:00.000  2017-02-10T19:05:00.000    DEP
#
#                                   agency_name complaint_type  \
# 27423  Department of Environmental Protection          Sewer
# 27424  Department of Environmental Protection          Sewer
# 27425  Department of Environmental Protection          Sewer
# 27426  Department of Environmental Protection          Sewer
# 27427  Department of Environmental Protection          Sewer
#
#                  descriptor  incident_zip         incident_address  \
# 27423  Street Flooding (SJ)      10037.00  458 MALCOLM X BOULEVARD
# 27424  Street Flooding (SJ)      11427.00      88-23 MOLINE STREET
# 27425  Street Flooding (SJ)      11360.00                      NaN
# 27426  Street Flooding (SJ)      11210.00                      NaN
# 27427  Street Flooding (SJ)      11221.00       80 BLEECKER STREET
#
#                street_name  ... park_facility_name park_borough latitude  \
# 27423  MALCOLM X BOULEVARD  ...        Unspecified    MANHATTAN    40.81
# 27424        MOLINE STREET  ...        Unspecified       QUEENS    40.73
# 27425                  NaN  ...        Unspecified       QUEENS    40.79
# 27426                  NaN  ...        Unspecified     BROOKLYN    40.62
# 27427      BLEECKER STREET  ...        Unspecified     BROOKLYN    40.69
#
#       longitude                                           location  \
# 27423    -73.94  {'latitude': '40.81266447489204', 'longitude':...
# 27424    -73.73  {'latitude': '40.72996113065443', 'longitude':...
# 27425    -73.78  {'latitude': '40.78883632109775', 'longitude':...
# 27426    -73.94  {'latitude': '40.61971464149482', 'longitude':...
# 27427    -73.92  {'latitude': '40.69460646294161', 'longitude':...
#
#       intersection_street_1 intersection_street_2 location_type due_date  \
# 27423                   NaN                   NaN           NaN      NaN
# 27424                   NaN                   NaN           NaN      NaN
# 27425  CROSS ISLAND PARKWAY            209 STREET           NaN      NaN
# 27426        EAST 31 STREET              AVENUE M           NaN      NaN
# 27427                   NaN                   NaN           NaN      NaN
#
#        landmark
# 27423       NaN
# 27424       NaN
# 27425       NaN
# 27426       NaN
# 27427       NaN
#
# [5 rows x 34 columns]

# %%
print(flooding_311.shape)
# Out:
# (27428, 34)

# %% [markdown]
# # 3. Data Inspection

# %% [markdown]
# ## 3.1 Basic Data Inspection

# %%
# the object's type
type(flooding_311)
# Out:
# pandas.core.frame.DataFrame

# %%
# printing the columns of our dataframe
flooding_311.columns
# Out:
# Index(['unique_key', 'created_date', 'closed_date', 'agency', 'agency_name',
#        'complaint_type', 'descriptor', 'incident_zip', 'incident_address',
#        'street_name', 'cross_street_1', 'cross_street_2', 'address_type',
#        'city', 'facility_type', 'status', 'resolution_description',
#        'resolution_action_updated_date', 'community_board', 'bbl', 'borough',
#        'x_coordinate_state_plane', 'y_coordinate_state_plane',
#        'open_data_channel_type', 'park_facility_name', 'park_borough',
#        'latitude', 'longitude', 'location', 'intersection_street_1',
#        'intersection_street_2', 'location_type', 'due_date', 'landmark'],
#       dtype='object')

# %%
# printing the data types of our columns
flooding_311.dtypes
# Out:
# unique_key                          int64
# created_date                       object
# closed_date                        object
# agency                             object
# agency_name                        object
# complaint_type                     object
# descriptor                         object
# incident_zip                      float64
# incident_address                   object
# street_name                        object
# cross_street_1                     object
# cross_street_2                     object
# address_type                       object
# city                               object
# facility_type                     float64
# status                             object
# resolution_description             object
# resolution_action_updated_date     object
# community_board                    object
# bbl                               float64
# borough                            object
# x_coordinate_state_plane          float64
# y_coordinate_state_plane          float64
# open_data_channel_type             object
# park_facility_name                 object
# park_borough                       object
# latitude                          float64
# longitude                         float64
# location                           object
# intersection_street_1              object
# intersection_street_2              object
# location_type                     float64
# due_date                           object
# landmark                          float64
# dtype: object

# %%
# printing the column names, non-null counts, and data types of our columns
flooding_311.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27428 entries, 0 to 27427
# Data columns (total 34 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   unique_key                      27428 non-null  int64
#  1   created_date                    27428 non-null  object
#  2   closed_date                     27426 non-null  object
#  3   agency                          27428 non-null  object
#  4   agency_name                     27428 non-null  object
#  5   complaint_type                  27428 non-null  object
#  6   descriptor                      27428 non-null  object
#  7   incident_zip                    26575 non-null  float64
#  8   incident_address                17504 non-null  object
#  9   street_name                     17504 non-null  object
#  10  cross_street_1                  23722 non-null  object
#  11  cross_street_2                  23710 non-null  object
#  12  address_type                    27422 non-null  object
#  13  city                            26576 non-null  object
#  14  facility_type                   0 non-null      float64
#  15  status                          27428 non-null  object
#  16  resolution_description          27421 non-null  object
#  17  resolution_action_updated_date  27428 non-null  object
#  18  community_board                 27428 non-null  object
#  19  bbl                             15816 non-null  float64
#  20  borough                         27428 non-null  object
#  21  x_coordinate_state_plane        26491 non-null  float64
#  22  y_coordinate_state_plane        26491 non-null  float64
#  23  open_data_channel_type          27428 non-null  object
#  24  park_facility_name              27428 non-null  object
#  25  park_borough                    27428 non-null  object
#  26  latitude                        26491 non-null  float64
#  27  longitude                       26491 non-null  float64
#  28  location                        26491 non-null  object
#  29  intersection_street_1           9981 non-null   object
#  30  intersection_street_2           9981 non-null   object
#  31  location_type                   0 non-null      float64
#  32  due_date                        1 non-null      object
#  33  landmark                        0 non-null      float64
# dtypes: float64(9), int64(1), object(24)
# memory usage: 7.1+ MB

# %%
# counts of unique values of our datatypes 
flooding_311.dtypes.value_counts()
# Out:
# object     24
# float64     9
# int64       1
# dtype: int64

# %%
# printing index type
flooding_311.index
# Out:
# RangeIndex(start=0, stop=27428, step=1)

# %%
cols = flooding_311.columns

print('Inspecting data for unique columns (True/False)\n' + \
     ('-' * 47))

for i in cols:
    print(str(i) + ':', flooding_311[i].is_unique)
# Out:
# Inspecting data for unique columns (True/False)
# -----------------------------------------------
# unique_key: True
# created_date: False
# closed_date: False
# agency: False
# agency_name: False
# complaint_type: False
# descriptor: False
# incident_zip: False
# incident_address: False
# street_name: False
# cross_street_1: False
# cross_street_2: False
# address_type: False
# city: False
# facility_type: False
# status: False
# resolution_description: False
# resolution_action_updated_date: False
# community_board: False
# bbl: False
# borough: False
# x_coordinate_state_plane: False
# y_coordinate_state_plane: False
# open_data_channel_type: False
# park_facility_name: False
# park_borough: False
# latitude: False
# longitude: False
# location: False
# intersection_street_1: False
# intersection_street_2: False
# location_type: False
# due_date: False
# landmark: False

# %%
# printing True/False if column is unique on our unique key (DOITT_ID)
flooding_311['unique_key'].is_unique
# Out:
# True

# %%
# printing descriptive statistics of our numeric columns in our data
all_columns = flooding_311.columns
flooding_311[all_columns].astype(str).describe(include='all')[:2].T.sort_values(by='unique', 
                                                                                ascending=False)
# Out:
#                                 count unique
# unique_key                      27428  27428
# created_date                    27428  25975
# closed_date                     27428  25023
# resolution_action_updated_date  27428  25013
# latitude                        27428  16765
# longitude                       27428  16765
# location                        27428  16765
# x_coordinate_state_plane        27428  15444
# y_coordinate_state_plane        27428  15407
# incident_address                27428  12218
# bbl                             27428  10469
# cross_street_2                  27428   4659
# cross_street_1                  27428   4589
# street_name                     27428   4081
# intersection_street_2           27428   2827
# intersection_street_1           27428   2811
# incident_zip                    27428    189
# city                            27428     88
# community_board                 27428     73
# resolution_description          27428     62
# borough                         27428      6
# park_borough                    27428      6
# open_data_channel_type          27428      5
# address_type                    27428      4
# status                          27428      4
# due_date                        27428      2
# location_type                   27428      1
# agency_name                     27428      1
# park_facility_name              27428      1
# complaint_type                  27428      1
# agency                          27428      1
# facility_type                   27428      1
# descriptor                      27428      1
# landmark                        27428      1

# %%
flooding_311['descriptor'].value_counts()
# Out:
# Street Flooding (SJ)    27428
# Name: descriptor, dtype: int64

# %%
flooding_311['agency'].value_counts()
# Out:
# DEP    27428
# Name: agency, dtype: int64

# %%
flooding_311['agency_name'].value_counts()
# Out:
# Department of Environmental Protection    27428
# Name: agency_name, dtype: int64

# %%
flooding_311['complaint_type'].value_counts()
# Out:
# Sewer    27428
# Name: complaint_type, dtype: int64

# %%
flooding_311['status'].value_counts()
# Out:
# Closed      27421
# Pending         4
# Started         2
# Assigned        1
# Name: status, dtype: int64

# %%
flooding_311['resolution_description'].value_counts().reset_index().head()
# Out:
#                                                index  resolution_description
# 0  The Department of Environment Protection inspe...                   11344
# 1  The Department of Environmental Protection has...                    3952
# 2  The Department of Environmental Protection ins...                    3465
# 3  The Department of Environmental Protection inv...                    2881
# 4  The Department of Environmental Protection ins...                    1249

# %%
print('Top 10 Resolution Descriptions in Descending Order:\n')

for i in range(10):
    print(str(i + 1) + '.', \
          flooding_311['resolution_description'].value_counts().index[i], \
          '\nCount: ' \
          f"{flooding_311['resolution_description'].value_counts()[i]:,}" + \
          '\n')
# Out:
# Top 10 Resolution Descriptions in Descending Order:
#
# 1. The Department of Environment Protection inspected your complaint but could not find the problem you reported. If the condition persists, please call 311 (or 212-639-9675 if calling from a non-New York City area code) with more detailed information to submit a new complaint.
# Count: 11,344
#
# 2. The Department of Environmental Protection has determined that this issue was previously reported by another customer The original complaint is being addressed. If the condition persists, please call 311 (or 212-639-9675 if calling from a non-New York City area code) to submit a new complaint.
# Count: 3,952
#
# 3. The Department of Environmental Protection inspected your complaint and referred it to the Department of Transportation for further action. If the problem persists, please call 311 (or 212-639-9675 if calling from a non-New York City area code) to submit a new complaint.
# Count: 3,465
#
# 4. The Department of Environmental Protection investigated this complaint and resolved the street flooding.
# Count: 2,881
#
# 5. The Department of Environmental Protection inspected your complaint and cleaned the catch basin or inlet. If the condition returns, please call 311 (or 212-639-9675 if calling from a non-New York City area code) to submit a new complaint.
# Count: 1,249
#
# 6. The Department of Environmental Protection has investigated this complaint and found that debris was obstructing the catch basin.
# Count: 1,084
#
# 7. The status of this Service Request is currently not available online. Please call 311 for further assistance. If you are outside of New York City, please call (212) NEW-YORK (212-639-9675).
# Count: 619
#
# 8. The Department of Environmental Protection has determined that this issue was previously reported by another customer The original complaint is being addressed. If the condition persists, please call 311 (or 212-639-9675 if calling from a non-New York City area code) with more detailed information to submit a new complaint.
# Count: 603
#
# 9. The Department of Environmental Protection inspected your complaint and determined that the catch basin is now functioning properly.  If the condition returns, please call 311 (or 212-639-9675 if calling from a non-New York City area code) to submit a new complaint.
# Count: 565
#
# 10. The Department of Environmental Protection has investigated this complaint. Surcharge conditions have been confirmed, due to either a pump station malfunction, high tides, water main break, or another issue.
# Count: 204

# %%
flooding_311.created_date.min()
# Out:
# '2010-01-02T08:26:00.000'

# %%
flooding_311.created_date.max()
# Out:
# '2020-12-31T15:41:00.000'

# %%
print('This dataset is from', \
      flooding_311.created_date.min()[0:10], \
      'to', \
      flooding_311.created_date.max()[0:10] + \
      '.')
# Out:
# This dataset is from 2010-01-02 to 2020-12-31.

# %% [markdown]
# ## 3.2 Calcualting Summary Statistics

# %%
# display floats up to three decimals
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
# printing descriptive statistics of our numeric columns in our data
flooding_311.describe()
# Out:
#        unique_key  incident_zip  facility_type           bbl  \
# count    27428.00      26575.00           0.00      15816.00
# mean  32240462.88      10969.86            NaN 3700761123.31
# std    9145119.01        536.76            NaN 1075451518.51
# min   15639934.00      10001.00            NaN          0.00
# 25%   24209554.00      10312.00            NaN 3060562512.50
# 50%   32631370.50      11221.00            NaN 4069055005.00
# 75%   40019588.25      11385.00            NaN 4156502522.75
# max   48543132.00      11697.00            NaN 5080500078.00
#
#        x_coordinate_state_plane  y_coordinate_state_plane  latitude  \
# count                  26491.00                  26491.00  26491.00
# mean                 1005575.87                 186159.58     40.68
# std                    35049.08                  30573.55      0.08
# min                   913357.00                 121032.00     40.50
# 25%                   986927.00                 161238.00     40.61
# 50%                  1007562.00                 183608.00     40.67
# 75%                  1034057.50                 206502.00     40.73
# max                  1067279.00                 271876.00     40.91
#
#        longitude  location_type  landmark
# count   26491.00           0.00      0.00
# mean      -73.92            NaN       NaN
# std         0.13            NaN       NaN
# min       -74.25            NaN       NaN
# 25%       -73.99            NaN       NaN
# 50%       -73.92            NaN       NaN
# 75%       -73.82            NaN       NaN
# max       -73.70            NaN       NaN

# %%
flooding_311.describe(include=['O']).T
# Out:
#                                 count unique  \
# created_date                    27428  25975
# closed_date                     27426  25022
# agency                          27428      1
# agency_name                     27428      1
# complaint_type                  27428      1
# descriptor                      27428      1
# incident_address                17504  12217
# street_name                     17504   4080
# cross_street_1                  23722   4588
# cross_street_2                  23710   4658
# address_type                    27422      3
# city                            26576     87
# status                          27428      4
# resolution_description          27421     61
# resolution_action_updated_date  27428  25013
# community_board                 27428     73
# borough                         27428      6
# open_data_channel_type          27428      5
# park_facility_name              27428      1
# park_borough                    27428      6
# location                        26491  16764
# intersection_street_1            9981   2810
# intersection_street_2            9981   2826
# due_date                            1      1
#
#                                                                               top  \
# created_date                                              2011-08-28T00:00:00.000
# closed_date                                               2017-05-06T08:30:00.000
# agency                                                                        DEP
# agency_name                                Department of Environmental Protection
# complaint_type                                                              Sewer
# descriptor                                                   Street Flooding (SJ)
# incident_address                                   133-25 FRANCIS LEWIS BOULEVARD
# street_name                                                              BROADWAY
# cross_street_1                                                               BEND
# cross_street_2                                                           DEAD END
# address_type                                                              ADDRESS
# city                                                                     BROOKLYN
# status                                                                     Closed
# resolution_description          The Department of Environment Protection inspe...
# resolution_action_updated_date                            2017-05-06T08:30:00.000
# community_board                                                  02 STATEN ISLAND
# borough                                                                    QUEENS
# open_data_channel_type                                                      PHONE
# park_facility_name                                                    Unspecified
# park_borough                                                               QUEENS
# location                        {'latitude': '40.67637306593017', 'longitude':...
# intersection_street_1                                                    BROADWAY
# intersection_street_2                                                    BROADWAY
# due_date                                                  1900-01-02T00:00:00.000
#
#                                  freq
# created_date                       13
# closed_date                        36
# agency                          27428
# agency_name                     27428
# complaint_type                  27428
# descriptor                      27428
# incident_address                   58
# street_name                       116
# cross_street_1                    330
# cross_street_2                    481
# address_type                    16380
# city                             6831
# status                          27421
# resolution_description          11344
# resolution_action_updated_date     36
# community_board                  2033
# borough                         10900
# open_data_channel_type          16285
# park_facility_name              27428
# park_borough                    10900
# location                           58
# intersection_street_1              97
# intersection_street_2             168
# due_date                            1

# %%
# printing descriptive statistics of our numeric columns in our data
flooding_311.describe(include='all').T
# Out:
#                                  count unique  \
# unique_key                     27428.0    NaN
# created_date                     27428  25975
# closed_date                      27426  25022
# agency                           27428      1
# agency_name                      27428      1
# complaint_type                   27428      1
# descriptor                       27428      1
# incident_zip                   26575.0    NaN
# incident_address                 17504  12217
# street_name                      17504   4080
# cross_street_1                   23722   4588
# cross_street_2                   23710   4658
# address_type                     27422      3
# city                             26576     87
# facility_type                      0.0    NaN
# status                           27428      4
# resolution_description           27421     61
# resolution_action_updated_date   27428  25013
# community_board                  27428     73
# bbl                            15816.0    NaN
# borough                          27428      6
# x_coordinate_state_plane       26491.0    NaN
# y_coordinate_state_plane       26491.0    NaN
# open_data_channel_type           27428      5
# park_facility_name               27428      1
# park_borough                     27428      6
# latitude                       26491.0    NaN
# longitude                      26491.0    NaN
# location                         26491  16764
# intersection_street_1             9981   2810
# intersection_street_2             9981   2826
# location_type                      0.0    NaN
# due_date                             1      1
# landmark                           0.0    NaN
#
#                                                                               top  \
# unique_key                                                                    NaN
# created_date                                              2011-08-28T00:00:00.000
# closed_date                                               2017-05-06T08:30:00.000
# agency                                                                        DEP
# agency_name                                Department of Environmental Protection
# complaint_type                                                              Sewer
# descriptor                                                   Street Flooding (SJ)
# incident_zip                                                                  NaN
# incident_address                                   133-25 FRANCIS LEWIS BOULEVARD
# street_name                                                              BROADWAY
# cross_street_1                                                               BEND
# cross_street_2                                                           DEAD END
# address_type                                                              ADDRESS
# city                                                                     BROOKLYN
# facility_type                                                                 NaN
# status                                                                     Closed
# resolution_description          The Department of Environment Protection inspe...
# resolution_action_updated_date                            2017-05-06T08:30:00.000
# community_board                                                  02 STATEN ISLAND
# bbl                                                                           NaN
# borough                                                                    QUEENS
# x_coordinate_state_plane                                                      NaN
# y_coordinate_state_plane                                                      NaN
# open_data_channel_type                                                      PHONE
# park_facility_name                                                    Unspecified
# park_borough                                                               QUEENS
# latitude                                                                      NaN
# longitude                                                                     NaN
# location                        {'latitude': '40.67637306593017', 'longitude':...
# intersection_street_1                                                    BROADWAY
# intersection_street_2                                                    BROADWAY
# location_type                                                                 NaN
# due_date                                                  1900-01-02T00:00:00.000
# landmark                                                                      NaN
#
#                                  freq          mean           std        min  \
# unique_key                        NaN   32240462.88    9145119.01 15639934.0
# created_date                       13           NaN           NaN        NaN
# closed_date                        36           NaN           NaN        NaN
# agency                          27428           NaN           NaN        NaN
# agency_name                     27428           NaN           NaN        NaN
# complaint_type                  27428           NaN           NaN        NaN
# descriptor                      27428           NaN           NaN        NaN
# incident_zip                      NaN      10969.86        536.76    10001.0
# incident_address                   58           NaN           NaN        NaN
# street_name                       116           NaN           NaN        NaN
# cross_street_1                    330           NaN           NaN        NaN
# cross_street_2                    481           NaN           NaN        NaN
# address_type                    16380           NaN           NaN        NaN
# city                             6831           NaN           NaN        NaN
# facility_type                     NaN           NaN           NaN        NaN
# status                          27421           NaN           NaN        NaN
# resolution_description          11344           NaN           NaN        NaN
# resolution_action_updated_date     36           NaN           NaN        NaN
# community_board                  2033           NaN           NaN        NaN
# bbl                               NaN 3700761123.31 1075451518.51        0.0
# borough                         10900           NaN           NaN        NaN
# x_coordinate_state_plane          NaN    1005575.87      35049.08   913357.0
# y_coordinate_state_plane          NaN     186159.58      30573.55   121032.0
# open_data_channel_type          16285           NaN           NaN        NaN
# park_facility_name              27428           NaN           NaN        NaN
# park_borough                    10900           NaN           NaN        NaN
# latitude                          NaN         40.68          0.08       40.5
# longitude                         NaN        -73.92          0.13     -74.25
# location                           58           NaN           NaN        NaN
# intersection_street_1              97           NaN           NaN        NaN
# intersection_street_2             168           NaN           NaN        NaN
# location_type                     NaN           NaN           NaN        NaN
# due_date                            1           NaN           NaN        NaN
# landmark                          NaN           NaN           NaN        NaN
#
#                                         25%          50%           75%  \
# unique_key                       24209554.0   32631370.5   40019588.25
# created_date                            NaN          NaN           NaN
# closed_date                             NaN          NaN           NaN
# agency                                  NaN          NaN           NaN
# agency_name                             NaN          NaN           NaN
# complaint_type                          NaN          NaN           NaN
# descriptor                              NaN          NaN           NaN
# incident_zip                        10312.0      11221.0       11385.0
# incident_address                        NaN          NaN           NaN
# street_name                             NaN          NaN           NaN
# cross_street_1                          NaN          NaN           NaN
# cross_street_2                          NaN          NaN           NaN
# address_type                            NaN          NaN           NaN
# city                                    NaN          NaN           NaN
# facility_type                           NaN          NaN           NaN
# status                                  NaN          NaN           NaN
# resolution_description                  NaN          NaN           NaN
# resolution_action_updated_date          NaN          NaN           NaN
# community_board                         NaN          NaN           NaN
# bbl                            3060562512.5 4069055005.0 4156502522.75
# borough                                 NaN          NaN           NaN
# x_coordinate_state_plane           986927.0    1007562.0     1034057.5
# y_coordinate_state_plane           161238.0     183608.0      206502.0
# open_data_channel_type                  NaN          NaN           NaN
# park_facility_name                      NaN          NaN           NaN
# park_borough                            NaN          NaN           NaN
# latitude                              40.61        40.67         40.73
# longitude                            -73.99       -73.92        -73.82
# location                                NaN          NaN           NaN
# intersection_street_1                   NaN          NaN           NaN
# intersection_street_2                   NaN          NaN           NaN
# location_type                           NaN          NaN           NaN
# due_date                                NaN          NaN           NaN
# landmark                                NaN          NaN           NaN
#
#                                         max
# unique_key                       48543132.0
# created_date                            NaN
# closed_date                             NaN
# agency                                  NaN
# agency_name                             NaN
# complaint_type                          NaN
# descriptor                              NaN
# incident_zip                        11697.0
# incident_address                        NaN
# street_name                             NaN
# cross_street_1                          NaN
# cross_street_2                          NaN
# address_type                            NaN
# city                                    NaN
# facility_type                           NaN
# status                                  NaN
# resolution_description                  NaN
# resolution_action_updated_date          NaN
# community_board                         NaN
# bbl                            5080500078.0
# borough                                 NaN
# x_coordinate_state_plane          1067279.0
# y_coordinate_state_plane           271876.0
# open_data_channel_type                  NaN
# park_facility_name                      NaN
# park_borough                            NaN
# latitude                              40.91
# longitude                             -73.7
# location                                NaN
# intersection_street_1                   NaN
# intersection_street_2                   NaN
# location_type                           NaN
# due_date                                NaN
# landmark                                NaN

# %%
# returning the mode of our numeric columns (excluding our unique key = 'DOITT_ID') as 'mode'
mode = flooding_311.loc[:, flooding_311.columns != 'unique_key'].mode(numeric_only=False)

# renaming index to 'mode'
mode.rename(index={0: "mode"}, inplace=True)

# transposing and printing the mode ofour numeric columns (excluding our unique key = 'DOITT_ID')
mode.T
# Out:
#                                                                              mode
# created_date                                              2011-08-28T00:00:00.000
# closed_date                                               2017-05-06T08:30:00.000
# agency                                                                        DEP
# agency_name                                Department of Environmental Protection
# complaint_type                                                              Sewer
# descriptor                                                   Street Flooding (SJ)
# incident_zip                                                              10306.0
# incident_address                                   133-25 FRANCIS LEWIS BOULEVARD
# street_name                                                              BROADWAY
# cross_street_1                                                               BEND
# cross_street_2                                                           DEAD END
# address_type                                                              ADDRESS
# city                                                                     BROOKLYN
# facility_type                                                                 NaN
# status                                                                     Closed
# resolution_description          The Department of Environment Protection inspe...
# resolution_action_updated_date                            2017-05-06T08:30:00.000
# community_board                                                  02 STATEN ISLAND
# bbl                                                                  4129700015.0
# borough                                                                    QUEENS
# x_coordinate_state_plane                                                1056580.0
# y_coordinate_state_plane                                                 185805.0
# open_data_channel_type                                                      PHONE
# park_facility_name                                                    Unspecified
# park_borough                                                               QUEENS
# latitude                                                                    40.68
# longitude                                                                  -73.74
# location                        {'latitude': '40.67637306593017', 'longitude':...
# intersection_street_1                                                    BROADWAY
# intersection_street_2                                                    BROADWAY
# location_type                                                                 NaN
# due_date                                                  1900-01-02T00:00:00.000
# landmark                                                                      NaN

# %%
# compute pairwise correlation of columns, excluding NA/null values
flooding_311.corr()
# Out:
#                           unique_key  incident_zip  facility_type   bbl  \
# unique_key                      1.00          0.04            NaN -0.03
# incident_zip                    0.04          1.00            NaN  0.13
# facility_type                    NaN           NaN            NaN   NaN
# bbl                            -0.03          0.13            NaN  1.00
# x_coordinate_state_plane        0.03          0.71            NaN -0.20
# y_coordinate_state_plane        0.03         -0.10            NaN -0.58
# latitude                        0.03         -0.10            NaN -0.58
# longitude                       0.03          0.71            NaN -0.20
# location_type                    NaN           NaN            NaN   NaN
# landmark                         NaN           NaN            NaN   NaN
#
#                           x_coordinate_state_plane  y_coordinate_state_plane  \
# unique_key                                    0.03                      0.03
# incident_zip                                  0.71                     -0.10
# facility_type                                  NaN                       NaN
# bbl                                          -0.20                     -0.58
# x_coordinate_state_plane                      1.00                      0.46
# y_coordinate_state_plane                      0.46                      1.00
# latitude                                      0.46                      1.00
# longitude                                     1.00                      0.46
# location_type                                  NaN                       NaN
# landmark                                       NaN                       NaN
#
#                           latitude  longitude  location_type  landmark
# unique_key                    0.03       0.03            NaN       NaN
# incident_zip                 -0.10       0.71            NaN       NaN
# facility_type                  NaN        NaN            NaN       NaN
# bbl                          -0.58      -0.20            NaN       NaN
# x_coordinate_state_plane      0.46       1.00            NaN       NaN
# y_coordinate_state_plane      1.00       0.46            NaN       NaN
# latitude                      1.00       0.46            NaN       NaN
# longitude                     0.46       1.00            NaN       NaN
# location_type                  NaN        NaN            NaN       NaN
# landmark                       NaN        NaN            NaN       NaN

# %%
fig, ax = plt.subplots(figsize=(15,10))

sns.heatmap(flooding_311.corr(), 
            annot=True, 
            ax=ax)
# Out:
# <AxesSubplot:>

# %%
flooding_311.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27428 entries, 0 to 27427
# Data columns (total 34 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   unique_key                      27428 non-null  int64
#  1   created_date                    27428 non-null  object
#  2   closed_date                     27426 non-null  object
#  3   agency                          27428 non-null  object
#  4   agency_name                     27428 non-null  object
#  5   complaint_type                  27428 non-null  object
#  6   descriptor                      27428 non-null  object
#  7   incident_zip                    26575 non-null  float64
#  8   incident_address                17504 non-null  object
#  9   street_name                     17504 non-null  object
#  10  cross_street_1                  23722 non-null  object
#  11  cross_street_2                  23710 non-null  object
#  12  address_type                    27422 non-null  object
#  13  city                            26576 non-null  object
#  14  facility_type                   0 non-null      float64
#  15  status                          27428 non-null  object
#  16  resolution_description          27421 non-null  object
#  17  resolution_action_updated_date  27428 non-null  object
#  18  community_board                 27428 non-null  object
#  19  bbl                             15816 non-null  float64
#  20  borough                         27428 non-null  object
#  21  x_coordinate_state_plane        26491 non-null  float64
#  22  y_coordinate_state_plane        26491 non-null  float64
#  23  open_data_channel_type          27428 non-null  object
#  24  park_facility_name              27428 non-null  object
#  25  park_borough                    27428 non-null  object
#  26  latitude                        26491 non-null  float64
#  27  longitude                       26491 non-null  float64
#  28  location                        26491 non-null  object
#  29  intersection_street_1           9981 non-null   object
#  30  intersection_street_2           9981 non-null   object
#  31  location_type                   0 non-null      float64
#  32  due_date                        1 non-null      object
#  33  landmark                        0 non-null      float64
# dtypes: float64(9), int64(1), object(24)
# memory usage: 7.1+ MB

# %%
flooding_311.columns
# Out:
# Index(['unique_key', 'created_date', 'closed_date', 'agency', 'agency_name',
#        'complaint_type', 'descriptor', 'incident_zip', 'incident_address',
#        'street_name', 'cross_street_1', 'cross_street_2', 'address_type',
#        'city', 'facility_type', 'status', 'resolution_description',
#        'resolution_action_updated_date', 'community_board', 'bbl', 'borough',
#        'x_coordinate_state_plane', 'y_coordinate_state_plane',
#        'open_data_channel_type', 'park_facility_name', 'park_borough',
#        'latitude', 'longitude', 'location', 'intersection_street_1',
#        'intersection_street_2', 'location_type', 'due_date', 'landmark'],
#       dtype='object')

# %%
heatmap = flooding_311[['unique_key', 'created_date', 'closed_date', 'agency', 'agency_name',
                       'complaint_type', 'descriptor', 'incident_zip', 'incident_address',
                       'street_name', 'cross_street_1', 'cross_street_2', 'address_type',
                       'city', 'status', 'resolution_description',
                       'resolution_action_updated_date', 'community_board', 'borough',
                       'x_coordinate_state_plane', 'y_coordinate_state_plane',
                       'open_data_channel_type', 'park_facility_name', 'park_borough',
                       'latitude', 'longitude', 'location', 'intersection_street_1',
                       'intersection_street_2', 'bbl']]

# %%
fig, ax = plt.subplots(figsize=(15,10))

sns.heatmap(heatmap.corr(), 
            annot=True, 
            ax=ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 3.3 Identifying Null/NA Values

# %%
print('Sum of nulls in column:')
flooding_311.isna().sum().sort_values(ascending=False)
# Out:
# Sum of nulls in column:
# landmark                          27428
# location_type                     27428
# facility_type                     27428
# due_date                          27427
# intersection_street_2             17447
# intersection_street_1             17447
# bbl                               11612
# street_name                        9924
# incident_address                   9924
# cross_street_2                     3718
# cross_street_1                     3706
# location                            937
# longitude                           937
# latitude                            937
# x_coordinate_state_plane            937
# y_coordinate_state_plane            937
# incident_zip                        853
# city                                852
# resolution_description                7
# address_type                          6
# closed_date                           2
# park_facility_name                    0
# park_borough                          0
# unique_key                            0
# open_data_channel_type                0
# borough                               0
# community_board                       0
# created_date                          0
# status                                0
# descriptor                            0
# complaint_type                        0
# agency_name                           0
# agency                                0
# resolution_action_updated_date        0
# dtype: int64

# %%
print('Sum of nulls in all columns:')
flooding_311.isna().sum().sum()
# Out:
# Sum of nulls in all columns:
# 189894

# %%
print('Identifying nulls in column (True/False):')
flooding_311.isna().head()
# Out:
# Identifying nulls in column (True/False):
#    unique_key  created_date  closed_date  agency  agency_name  complaint_type  \
# 0       False         False        False   False        False           False
# 1       False         False        False   False        False           False
# 2       False         False        False   False        False           False
# 3       False         False        False   False        False           False
# 4       False         False        False   False        False           False
#
#    descriptor  incident_zip  incident_address  street_name  ...  \
# 0       False         False             False        False  ...
# 1       False         False              True         True  ...
# 2       False         False             False        False  ...
# 3       False         False              True         True  ...
# 4       False         False             False        False  ...
#
#    park_facility_name  park_borough  latitude  longitude  location  \
# 0               False         False     False      False     False
# 1               False         False     False      False     False
# 2               False         False     False      False     False
# 3               False         False     False      False     False
# 4               False         False     False      False     False
#
#    intersection_street_1  intersection_street_2  location_type  due_date  \
# 0                   True                   True           True      True
# 1                  False                  False           True      True
# 2                   True                   True           True      True
# 3                  False                  False           True      True
# 4                   True                   True           True      True
#
#    landmark
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#
# [5 rows x 34 columns]

# %%
print('Identifying any null values in column (True/False):')
flooding_311.isna().any().sort_values(ascending=False)
# Out:
# Identifying any null values in column (True/False):
# landmark                           True
# address_type                       True
# x_coordinate_state_plane           True
# bbl                                True
# latitude                           True
# longitude                          True
# resolution_description             True
# location                           True
# facility_type                      True
# city                               True
# cross_street_2                     True
# cross_street_1                     True
# street_name                        True
# incident_address                   True
# incident_zip                       True
# intersection_street_1              True
# intersection_street_2              True
# location_type                      True
# due_date                           True
# closed_date                        True
# y_coordinate_state_plane           True
# park_facility_name                False
# park_borough                      False
# unique_key                        False
# open_data_channel_type            False
# borough                           False
# community_board                   False
# created_date                      False
# status                            False
# descriptor                        False
# complaint_type                    False
# agency_name                       False
# agency                            False
# resolution_action_updated_date    False
# dtype: bool

# %%
# return a boolean same-sized object indicating if any of the values are NA
flooding_311.isna().any().value_counts()
# Out:
# True     21
# False    13
# dtype: int64

# %%
# return descriptive statistics of boolean indicating if any of the values are NA
flooding_311.isna().any().describe()
# Out:
# count       34
# unique       2
# top       True
# freq        21
# dtype: object

# %%
# calculating a percentage of the number of nulls to total number of records of each column
missing_data = (flooding_311.isna().sum() / len(flooding_311)) * 100

# creating a dataframe
missing_data = pd.DataFrame({'Missing Ratio (%)' :missing_data}) 
missing_data.sort_values(by='Missing Ratio (%)', 
                         ascending=False, 
                         inplace=True)

missing_data.head(len(missing_data))
# Out:
#                                 Missing Ratio (%)
# landmark                                   100.00
# location_type                              100.00
# facility_type                              100.00
# due_date                                   100.00
# intersection_street_2                       63.61
# intersection_street_1                       63.61
# bbl                                         42.34
# street_name                                 36.18
# incident_address                            36.18
# cross_street_2                              13.56
# cross_street_1                              13.51
# location                                     3.42
# longitude                                    3.42
# latitude                                     3.42
# x_coordinate_state_plane                     3.42
# y_coordinate_state_plane                     3.42
# incident_zip                                 3.11
# city                                         3.11
# resolution_description                       0.03
# address_type                                 0.02
# closed_date                                  0.01
# park_facility_name                           0.00
# park_borough                                 0.00
# unique_key                                   0.00
# open_data_channel_type                       0.00
# borough                                      0.00
# community_board                              0.00
# created_date                                 0.00
# status                                       0.00
# descriptor                                   0.00
# complaint_type                               0.00
# agency_name                                  0.00
# agency                                       0.00
# resolution_action_updated_date               0.00

# %% [markdown]
# ## 3.4 Inspecting Items In Each Column

# %%
len(flooding_311.columns)
# Out:
# 34

# %%
flooding_311.iloc[:,:15].head()
# Out:
#    unique_key             created_date              closed_date agency  \
# 0    35467474  2017-02-11T14:49:00.000  2017-02-17T11:19:00.000    DEP
# 1    35473543  2017-02-12T19:03:00.000  2017-02-12T19:03:00.000    DEP
# 2    35475940  2017-02-12T14:38:00.000  2017-02-12T15:20:00.000    DEP
# 3    35478538  2017-02-13T13:11:00.000  2017-02-15T09:30:00.000    DEP
# 4    35479396  2017-02-13T07:26:00.000  2017-02-13T08:10:00.000    DEP
#
#                               agency_name complaint_type  \
# 0  Department of Environmental Protection          Sewer
# 1  Department of Environmental Protection          Sewer
# 2  Department of Environmental Protection          Sewer
# 3  Department of Environmental Protection          Sewer
# 4  Department of Environmental Protection          Sewer
#
#              descriptor  incident_zip       incident_address  \
# 0  Street Flooding (SJ)      10312.00     152 BARCLAY AVENUE
# 1  Street Flooding (SJ)      11231.00                    NaN
# 2  Street Flooding (SJ)      10465.00    659 CLARENCE AVENUE
# 3  Street Flooding (SJ)      11210.00                    NaN
# 4  Street Flooding (SJ)      10466.00  1635 EAST  233 STREET
#
#         street_name cross_street_1 cross_street_2  address_type  \
# 0    BARCLAY AVENUE     MOSELY AVE      SUMMIT PL       ADDRESS
# 1               NaN            NaN            NaN  INTERSECTION
# 2   CLARENCE AVENUE     SCHLEY AVE    RANDALL AVE       ADDRESS
# 3               NaN            NaN            NaN  INTERSECTION
# 4  EAST  233 STREET    PROVOST AVE  CLEMENTINE ST       ADDRESS
#
#             city  facility_type
# 0  STATEN ISLAND            NaN
# 1       BROOKLYN            NaN
# 2          BRONX            NaN
# 3       BROOKLYN            NaN
# 4          BRONX            NaN

# %%
flooding_311.iloc[:,15:30].head()
# Out:
#    status                             resolution_description  \
# 0  Closed  The Department of Environmental Protection has...
# 1  Closed  The Department of Environmental Protection has...
# 2  Closed  The Department of Environmental Protection res...
# 3  Closed  The Department of Environmental Protection ins...
# 4  Closed  The Department of Environment Protection inspe...
#
#   resolution_action_updated_date   community_board           bbl  \
# 0        2017-02-17T11:19:00.000  03 STATEN ISLAND 5062420038.00
# 1        2017-02-12T19:03:00.000       06 BROOKLYN           NaN
# 2        2017-02-12T15:20:00.000          10 BRONX 2054850051.00
# 3        2017-02-15T09:30:00.000       18 BROOKLYN           NaN
# 4        2017-02-13T08:10:00.000          12 BRONX 2049740028.00
#
#          borough  x_coordinate_state_plane  y_coordinate_state_plane  \
# 0  STATEN ISLAND                 935649.00                 135719.00
# 1       BROOKLYN                 986505.00                 185906.00
# 2          BRONX                1035641.00                 241247.00
# 3       BROOKLYN                 999910.00                 165097.00
# 4          BRONX                1032111.00                 262916.00
#
#   open_data_channel_type park_facility_name   park_borough  latitude  \
# 0                  PHONE        Unspecified  STATEN ISLAND     40.54
# 1                 ONLINE        Unspecified       BROOKLYN     40.68
# 2                 ONLINE        Unspecified          BRONX     40.83
# 3                  PHONE        Unspecified       BROOKLYN     40.62
# 4                  PHONE        Unspecified          BRONX     40.89
#
#    longitude                                           location  \
# 0     -74.17  {'latitude': '40.53905963837945', 'longitude':...
# 1     -73.99  {'latitude': '40.67694549612395', 'longitude':...
# 2     -73.81  {'latitude': '40.82869324687791', 'longitude':...
# 3     -73.94  {'latitude': '40.61981574824473', 'longitude':...
# 4     -73.83  {'latitude': '40.88818786782963', 'longitude':...
#
#   intersection_street_1
# 0                   NaN
# 1              3 STREET
# 2                   NaN
# 3        EAST 32 STREET
# 4                   NaN

# %%
flooding_311.iloc[:,30:].head()
# Out:
#   intersection_street_2  location_type due_date  landmark
# 0                   NaN            NaN      NaN       NaN
# 1           BOND STREET            NaN      NaN       NaN
# 2                   NaN            NaN      NaN       NaN
# 3              AVENUE M            NaN      NaN       NaN
# 4                   NaN            NaN      NaN       NaN

# %%
print('Returning a dataframe containing counts and normalized counts of unique rows in each column (sorted desc).',
     '\n' + '-' * 60, '\n')

for col in flooding_311.columns:
    series_1 = flooding_311[col].value_counts().head()
    series_2 = flooding_311[col].value_counts(normalize=True).head()
    series_2 = series_2.rename(str(col) +  ' (normalized)')
    value_counts = pd.concat([series_1, series_2], axis=1)
    
    print(value_counts, '\n' \
         'Column Name:', col + ',', 'dtype:', flooding_311[col].dtype, '\n')
# Out:
# Returning a dataframe containing counts and normalized counts of unique rows in each column (sorted desc).
# ------------------------------------------------------------
#
#           unique_key  unique_key (normalized)
# 16912386           1                     0.00
# 34671374           1                     0.00
# 18551703           1                     0.00
# 28195057           1                     0.00
# 21377939           1                     0.00
# Column Name: unique_key, dtype: int64
#
#                          created_date  created_date (normalized)
# 2011-08-28T00:00:00.000            13                       0.00
# 2019-10-27T13:22:00.000             7                       0.00
# 2011-08-29T00:00:00.000             6                       0.00
# 2017-05-05T13:49:00.000             6                       0.00
# 2018-11-26T18:33:00.000             5                       0.00
# Column Name: created_date, dtype: object
#
#                          closed_date  closed_date (normalized)
# 2017-05-06T08:30:00.000           36                      0.00
# 2019-12-18T09:30:00.000           17                      0.00
# 2018-09-28T10:30:00.000           13                      0.00
# 2019-12-20T09:30:00.000           12                      0.00
# 2019-05-14T09:30:00.000           12                      0.00
# Column Name: closed_date, dtype: object
#
#      agency  agency (normalized)
# DEP   27428                 1.00
# Column Name: agency, dtype: object
#
#                                         agency_name  agency_name (normalized)
# Department of Environmental Protection        27428                      1.00
# Column Name: agency_name, dtype: object
#
#        complaint_type  complaint_type (normalized)
# Sewer           27428                         1.00
# Column Name: complaint_type, dtype: object
#
#                       descriptor  descriptor (normalized)
# Street Flooding (SJ)       27428                     1.00
# Column Name: descriptor, dtype: object
#
#           incident_zip  incident_zip (normalized)
# 10306.00          1385                       0.05
# 11691.00           719                       0.03
# 10314.00           663                       0.02
# 10312.00           606                       0.02
# 10305.00           595                       0.02
# Column Name: incident_zip, dtype: float64
#
#                                 incident_address  \
# 133-25 FRANCIS LEWIS BOULEVARD                58
# 575 MILL ROAD                                 49
# 131 GRIMSBY STREET                            49
# 78-02 149 AVENUE                              43
# 114-48 141 STREET                             39
#
#                                 incident_address (normalized)
# 133-25 FRANCIS LEWIS BOULEVARD                           0.00
# 575 MILL ROAD                                            0.00
# 131 GRIMSBY STREET                                       0.00
# 78-02 149 AVENUE                                         0.00
# 114-48 141 STREET                                        0.00
# Column Name: incident_address, dtype: object
#
#                          street_name  street_name (normalized)
# BROADWAY                         116                      0.01
# 78 STREET                        102                      0.01
# FRANCIS LEWIS BOULEVARD           94                      0.01
# GRIMSBY STREET                    87                      0.00
# 141 STREET                        78                      0.00
# Column Name: street_name, dtype: object
#
#                   cross_street_1  cross_street_1 (normalized)
# BEND                         330                         0.01
# DEAD END                     266                         0.01
# LINDEN BLVD                  209                         0.01
# 259 ST                       130                         0.01
# BEACH CHANNEL DR             119                         0.01
# Column Name: cross_street_1, dtype: object
#
#                     cross_street_2  cross_street_2 (normalized)
# DEAD END                       481                         0.02
# BEND                           392                         0.02
# BROADWAY                       145                         0.01
# FRANCIS LEWIS BLVD             125                         0.01
# BEACH CHANNEL DR               120                         0.01
# Column Name: cross_street_2, dtype: object
#
#               address_type  address_type (normalized)
# ADDRESS              16380                       0.60
# INTERSECTION         10052                       0.37
# BLOCKFACE              990                       0.04
# Column Name: address_type, dtype: object
#
#                city  city (normalized)
# BROOKLYN       6831               0.26
# STATEN ISLAND  4843               0.18
# NEW YORK       2493               0.09
# BRONX          1902               0.07
# Jamaica        1192               0.04
# Column Name: city, dtype: object
#
# Empty DataFrame
# Columns: [facility_type, facility_type (normalized)]
# Index: []
# Column Name: facility_type, dtype: float64
#
#           status  status (normalized)
# Closed     27421                 1.00
# Pending        4                 0.00
# Started        2                 0.00
# Assigned       1                 0.00
# Column Name: status, dtype: object
#
#                                                     resolution_description  \
# The Department of Environment Protection inspec...                   11344
# The Department of Environmental Protection has ...                    3952
# The Department of Environmental Protection insp...                    3465
# The Department of Environmental Protection inve...                    2881
# The Department of Environmental Protection insp...                    1249
#
#                                                     resolution_description (normalized)
# The Department of Environment Protection inspec...                                 0.41
# The Department of Environmental Protection has ...                                 0.14
# The Department of Environmental Protection insp...                                 0.13
# The Department of Environmental Protection inve...                                 0.11
# The Department of Environmental Protection insp...                                 0.05
# Column Name: resolution_description, dtype: object
#
#                          resolution_action_updated_date  \
# 2017-05-06T08:30:00.000                              36
# 2019-12-18T09:30:00.000                              17
# 2018-09-28T10:30:00.000                              13
# 2019-12-20T09:30:00.000                              12
# 2019-05-14T09:30:00.000                              12
#
#                          resolution_action_updated_date (normalized)
# 2017-05-06T08:30:00.000                                         0.00
# 2019-12-18T09:30:00.000                                         0.00
# 2018-09-28T10:30:00.000                                         0.00
# 2019-12-20T09:30:00.000                                         0.00
# 2019-05-14T09:30:00.000                                         0.00
# Column Name: resolution_action_updated_date, dtype: object
#
#                   community_board  community_board (normalized)
# 02 STATEN ISLAND             2033                          0.07
# 13 QUEENS                    1811                          0.07
# 03 STATEN ISLAND             1652                          0.06
# 14 QUEENS                    1595                          0.06
# 12 QUEENS                    1471                          0.05
# Column Name: community_board, dtype: object
#
#                bbl  bbl (normalized)
# 4129700015.00   58              0.00
# 5037950147.00   49              0.00
# 5046840017.00   49              0.00
# 4114100072.00   48              0.00
# 4119700029.00   41              0.00
# Column Name: bbl, dtype: float64
#
#                borough  borough (normalized)
# QUEENS           10900                  0.40
# BROOKLYN          6970                  0.25
# STATEN ISLAND     4925                  0.18
# MANHATTAN         2583                  0.09
# BRONX             2039                  0.07
# Column Name: borough, dtype: object
#
#             x_coordinate_state_plane  x_coordinate_state_plane (normalized)
# 1056580.00                        58                                   0.00
# 986291.00                         55                                   0.00
# 1050401.00                        49                                   0.00
# 951870.00                         49                                   0.00
# 958363.00                         49                                   0.00
# Column Name: x_coordinate_state_plane, dtype: float64
#
#            y_coordinate_state_plane  y_coordinate_state_plane (normalized)
# 185805.00                        59                                   0.00
# 215593.00                        54                                   0.00
# 141733.00                        49                                   0.00
# 148793.00                        49                                   0.00
# 182901.00                        48                                   0.00
# Column Name: y_coordinate_state_plane, dtype: float64
#
#          open_data_channel_type  open_data_channel_type (normalized)
# PHONE                     16285                                 0.59
# UNKNOWN                    7230                                 0.26
# ONLINE                     3711                                 0.14
# OTHER                       201                                 0.01
# MOBILE                        1                                 0.00
# Column Name: open_data_channel_type, dtype: object
#
#              park_facility_name  park_facility_name (normalized)
# Unspecified               27428                             1.00
# Column Name: park_facility_name, dtype: object
#
#                park_borough  park_borough (normalized)
# QUEENS                10900                       0.40
# BROOKLYN               6970                       0.25
# STATEN ISLAND          4925                       0.18
# MANHATTAN              2583                       0.09
# BRONX                  2039                       0.07
# Column Name: park_borough, dtype: object
#
#        latitude  latitude (normalized)
# 40.68        58                   0.00
# 40.76        54                   0.00
# 40.56        49                   0.00
# 40.58        49                   0.00
# 40.67        48                   0.00
# Column Name: latitude, dtype: float64
#
#         longitude  longitude (normalized)
# -73.74         58                    0.00
# -73.99         54                    0.00
# -74.12         49                    0.00
# -74.09         49                    0.00
# -73.76         48                    0.00
# Column Name: longitude, dtype: float64
#
#                                                     location  \
# {'latitude': '40.67637306593017', 'longitude': ...        58
# {'latitude': '40.75842923013922', 'longitude': ...        54
# {'latitude': '40.55564095666517', 'longitude': ...        49
# {'latitude': '40.57504060779978', 'longitude': ...        49
# {'latitude': '40.69673811577188', 'longitude': ...        48
#
#                                                     location (normalized)
# {'latitude': '40.67637306593017', 'longitude': ...                   0.00
# {'latitude': '40.75842923013922', 'longitude': ...                   0.00
# {'latitude': '40.55564095666517', 'longitude': ...                   0.00
# {'latitude': '40.57504060779978', 'longitude': ...                   0.00
# {'latitude': '40.69673811577188', 'longitude': ...                   0.00
# Column Name: location, dtype: object
#
#                      intersection_street_1  intersection_street_1 (normalized)
# BROADWAY                                97                                0.01
# 12 AVENUE                               72                                0.01
# HYLAN BOULEVARD                         58                                0.01
# ARTHUR KILL ROAD                        58                                0.01
# METROPOLITAN AVENUE                     53                                0.01
# Column Name: intersection_street_1, dtype: object
#
#                 intersection_street_2  intersection_street_2 (normalized)
# BROADWAY                          168                                0.02
# 1 AVENUE                           79                                0.01
# 3 AVENUE                           59                                0.01
# BEDFORD AVENUE                     55                                0.01
# 147 AVENUE                         55                                0.01
# Column Name: intersection_street_2, dtype: object
#
# Empty DataFrame
# Columns: [location_type, location_type (normalized)]
# Index: []
# Column Name: location_type, dtype: float64
#
#                          due_date  due_date (normalized)
# 1900-01-02T00:00:00.000         1                   1.00
# Column Name: due_date, dtype: object
#
# Empty DataFrame
# Columns: [landmark, landmark (normalized)]
# Index: []
# Column Name: landmark, dtype: float64
