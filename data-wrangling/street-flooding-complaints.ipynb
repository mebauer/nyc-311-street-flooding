# %% [markdown]
# # Downloading NYC 311 Street Flooding Complaints Data Using Sodapy
#
# Author: Mark Bauer

# %%
# importing libraries
import os
import numpy as np
import pandas as pd
from sodapy import Socrata
from datetime import datetime

# %%
# reproducibility
# %reload_ext watermark
# %watermark -v -p numpy,pandas,sodapy
# Out:
# Python implementation: CPython
# Python version       : 3.11.0
# IPython version      : 8.6.0
#
# numpy : 1.23.4
# pandas: 1.5.1
# sodapy: 2.2.0

# %%
# data retrieved
current_date = datetime.now()
print(f"The data was retrieved on {current_date.strftime('%Y-%m-%d')}.")
# Out:
# The data was retrieved on 2025-04-06.

# %% [markdown]
# # Sodapy
# The Python client for the Socrata API.

# %%
# nyc open data domain and 311 dataset id
socrata_domain = 'data.cityofnewyork.us'
socrata_dataset_identifier = 'erm2-nwe9'

# %% [markdown]
# For now, we'll use the Socrata API without a token, but the steps to use one are below.

# %%
# If you choose to use a token, run the following command on the terminal (or add it to your .bashrc)
# $ export SODAPY_APPTOKEN=<token>
# socrata_token = os.environ.get("SODAPY_APPTOKEN")

# %% [markdown]
# # Preview and Explore the NYC 311 Dataset
# Practice querying data using the sodapy client.

# %%
# Socrata object to fetch data
client = Socrata(
    domain=socrata_domain,
    app_token=None,
    timeout=1000
)

# inspect
print(client)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# <sodapy.socrata.Socrata object at 0x10c5cbcd0>

# %% [markdown]
# We use the sodapy `get` method to fetch data. Pass the `dataset id` and the `query` to this method.

# %% [markdown]
# **Table xx:** Number of NYC 311 Complaints by Complaint Type.

# %%
query = """
    SELECT 
        complaint_type, 
        count(complaint_type) AS count  
    GROUP BY 
        complaint_type   
    ORDER BY 
        count(complaint_type) DESC
    LIMIT
        20
"""

# returned as JSON from API, converted to Python list of dictionaries by sodapy
results = client.get(socrata_dataset_identifier, query=query)

# convert to pandas DataFrame
results_df = pd.DataFrame(results)

print(f'shape of data: {results_df.shape}')
results_df
# Out:
# shape of data: (20, 2)
#                          complaint_type    count
# 0                   Noise - Residential  3763852
# 1                       Illegal Parking  2963250
# 2                        HEAT/HOT WATER  2496471
# 3                      Blocked Driveway  1726104
# 4               Noise - Street/Sidewalk  1345355
# 5                      Street Condition  1326391
# 6                Street Light Condition  1166688
# 7   Request Large Bulky Item Collection  1073753
# 8                              PLUMBING  1002879
# 9                  UNSANITARY CONDITION   964080
# 10                         Water System   953033
# 11                              HEATING   887869
# 12                                Noise   739114
# 13        General Construction/Plumbing   689926
# 14                   Noise - Commercial   659128
# 15             Traffic Signal Condition   639489
# 16                        PAINT/PLASTER   621667
# 17                      Noise - Vehicle   555418
# 18                                Sewer   513264
# 19                 GENERAL CONSTRUCTION   500813

# %% [markdown]
# **Table xx:** Number of NYC 311 Complaints by Descriptor.

# %%
query = """
    SELECT 
        descriptor, 
        count(descriptor) AS count 
    GROUP BY 
        descriptor    
    ORDER BY 
        count(descriptor) DESC
    LIMIT
        20
"""

results = client.get(socrata_dataset_identifier, query=query)
results_df = pd.DataFrame(results)

print(f'shape of data: {results_df.shape}')
results_df
# Out:
# shape of data: (20, 2)
#                              descriptor    count
# 0                      Loud Music/Party  4116161
# 1                       ENTIRE BUILDING  1630913
# 2                             No Access  1279789
# 3   Request Large Bulky Item Collection  1073753
# 4                      Banging/Pounding  1052889
# 5                                  HEAT   868960
# 6                        APARTMENT ONLY   865558
# 7                      Street Light Out   858510
# 8                       Blocked Hydrant   827115
# 9                               Pothole   800141
# 10        Posted Parking Sign Violation   727000
# 11                         Loud Talking   601057
# 12                                  N/A   574490
# 13                   With License Plate   529766
# 14                                PESTS   492532
# 15                              CEILING   468805
# 16                       Partial Access   446323
# 17                    Derelict Vehicles   445255
# 18                                 MOLD   396205
# 19                     Blocked Sidewalk   389113

# %% [markdown]
# **Table xx:** Number of NYC 311 Complaints by Complaint Type and Descriptor.

# %%
query = """
    SELECT 
        complaint_type,
        descriptor, 
        count(*) AS count  
    GROUP BY 
        complaint_type, descriptor   
    ORDER BY 
        count(*) DESC
    LIMIT
        20
"""

results = client.get(socrata_dataset_identifier, query=query)
results_df = pd.DataFrame(results)

print(f'shape of data: {results_df.shape}')
results_df
# Out:
# shape of data: (20, 3)
#                          complaint_type                           descriptor  \
# 0                   Noise - Residential                     Loud Music/Party
# 1                        HEAT/HOT WATER                      ENTIRE BUILDING
# 2                      Blocked Driveway                            No Access
# 3   Request Large Bulky Item Collection  Request Large Bulky Item Collection
# 4               Noise - Street/Sidewalk                     Loud Music/Party
# 5                   Noise - Residential                     Banging/Pounding
# 6                               HEATING                                 HEAT
# 7                        HEAT/HOT WATER                       APARTMENT ONLY
# 8                Street Light Condition                     Street Light Out
# 9                       Illegal Parking                      Blocked Hydrant
# 10                     Street Condition                              Pothole
# 11                      Illegal Parking        Posted Parking Sign Violation
# 12                   Noise - Commercial                     Loud Music/Party
# 13                 UNSANITARY CONDITION                                PESTS
# 14                     Blocked Driveway                       Partial Access
# 15                    Derelict Vehicles                    Derelict Vehicles
# 16                      Illegal Parking                     Blocked Sidewalk
# 17                      Noise - Vehicle                      Car/Truck Music
# 18             Traffic Signal Condition                           Controller
# 19                    Abandoned Vehicle                   With License Plate
#
#       count
# 0   2483557
# 1   1630913
# 2   1279783
# 3   1073753
# 4   1050249
# 5    985237
# 6    868960
# 7    865558
# 8    858510
# 9    825059
# 10   797503
# 11   724109
# 12   506207
# 13   492532
# 14   446319
# 15   445255
# 16   387242
# 17   334475
# 18   331492
# 19   321952

# %% [markdown]
# **Table xx:** Number of NYC 311 Complaints by Complaint Type Where Complaint Type Contains the Word *flood*.

# %%
query = """
    SELECT 
        complaint_type, 
        count(complaint_type)
    WHERE 
        LOWER(complaint_type) LIKE '%flood%'   
    GROUP BY 
        complaint_type
    ORDER BY 
        count(complaint_type) DESC
    LIMIT
        10
"""

results = client.get(socrata_dataset_identifier, query=query)
results_df = pd.DataFrame(results)

print(f'shape of data: {results_df.shape}')
results_df
# Out:
# shape of data: (0, 0)
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# **Table xx:** Number of NYC 311 Complaints by Descriptor Where Descriptor Contains the Word *flood*.

# %%
query = """
    SELECT 
        descriptor, 
        count(descriptor) AS count
    WHERE 
        LOWER(descriptor) LIKE '%flood%' 
    GROUP BY 
        descriptor  
    ORDER BY 
        count(descriptor) DESC
    LIMIT
        20 
"""

results = client.get(socrata_dataset_identifier, query=query)
results_df = pd.DataFrame(results)

print(f'shape of data: {results_df.shape}')
results_df
# Out:
# shape of data: (13, 2)
#                                           descriptor   count
# 0   Catch Basin Clogged/Flooding (Use Comments) (SC)  119775
# 1                               Street Flooding (SJ)   41687
# 2                               Flood Light Lamp Out    6634
# 3                              Highway Flooding (SH)    3192
# 4                           Flood Light Lamp Cycling    2621
# 5                                 Flooding on Street     673
# 6                                Ready NY - Flooding     271
# 7                        Flood Light Lamp Dayburning     242
# 8                           Flood Light Lamp Missing     216
# 9                               Flood Light Lamp Dim     198
# 10                     RAIN GARDEN FLOODING (SRGFLD)     152
# 11                                           Flooded      57
# 12                               Flooding on Highway      15

# %% [markdown]
# # 311 Street Flooding Complaints

# %% [markdown]
# Select all rows where `descriptor` is `Street Flooding (SJ)` and `created_date` is `between 2010 and 2020`. We use limit 100,000 as an approximate of all possible rows.

# %%
query = """
    SELECT 
        *
    WHERE 
        descriptor == 'Street Flooding (SJ)'
        AND created_date BETWEEN '2010' AND '2020'
    LIMIT
        100000 -- must do this, assign a large number
"""

results = client.get(socrata_dataset_identifier, query=query)
results_df = pd.DataFrame(results)

print(f'shape of data: {results_df.shape}')
results_df
# Out:
# shape of data: (25747, 32)
#       unique_key             created_date              closed_date agency  \
# 0       18265181  2010-07-14T08:38:00.000  2010-07-14T08:38:00.000    DEP
# 1       34783066  2016-11-15T09:27:00.000  2016-11-15T10:05:00.000    DEP
# 2       21549616  2011-09-29T10:34:00.000  2011-09-30T10:40:00.000    DEP
# 3       35839080  2017-03-31T20:24:00.000  2017-04-01T02:25:00.000    DEP
# 4       29443390  2014-12-06T10:23:00.000  2014-12-06T11:30:00.000    DEP
# ...          ...                      ...                      ...    ...
# 25742   45073978  2019-12-03T10:54:00.000  2019-12-30T22:01:00.000    DEP
# 25743   45054586  2019-11-30T13:00:00.000  2019-11-30T22:25:00.000    DEP
# 25744   26909821  2013-12-18T11:49:00.000  2013-12-19T10:25:00.000    DEP
# 25745   43351039  2019-07-22T22:06:00.000  2019-07-23T10:50:00.000    DEP
# 25746   42865536  2019-06-04T12:51:00.000  2019-06-05T09:00:00.000    DEP
#
#                                   agency_name complaint_type  \
# 0      Department of Environmental Protection          Sewer
# 1      Department of Environmental Protection          Sewer
# 2      Department of Environmental Protection          Sewer
# 3      Department of Environmental Protection          Sewer
# 4      Department of Environmental Protection          Sewer
# ...                                       ...            ...
# 25742  Department of Environmental Protection          Sewer
# 25743  Department of Environmental Protection          Sewer
# 25744  Department of Environmental Protection          Sewer
# 25745  Department of Environmental Protection          Sewer
# 25746  Department of Environmental Protection          Sewer
#
#                  descriptor  cross_street_1 cross_street_2  \
# 0      Street Flooding (SJ)     PELHAM PKWY  STILLWELL AVE
# 1      Street Flooding (SJ)             NaN            NaN
# 2      Street Flooding (SJ)             NaN            NaN
# 3      Street Flooding (SJ)        3 AVENUE       2 AVENUE
# 4      Street Flooding (SJ)       NAGLE AVE     DYCKMAN ST
# ...                     ...             ...            ...
# 25742  Street Flooding (SJ)      SEAVER AVE        IONA ST
# 25743  Street Flooding (SJ)       INWOOD ST         146 ST
# 25744  Street Flooding (SJ)           82 PL         63 AVE
# 25745  Street Flooding (SJ)           2 AVE           9 ST
# 25746  Street Flooding (SJ)  NORTHFIELD AVE       DEAD END
#
#       intersection_street_1  ...            city x_coordinate_state_plane  \
# 0               PELHAM PKWY  ...             NaN                      NaN
# 1          LAFAYETTE AVENUE  ...   STATEN ISLAND                   958594
# 2               THURSBY AVE  ...             NaN                      NaN
# 3                       NaN  ...        NEW YORK                      NaN
# 4                 NAGLE AVE  ...             NaN                      NaN
# ...                     ...  ...             ...                      ...
# 25742                   NaN  ...   STATEN ISLAND                   960864
# 25743                   NaN  ...         Jamaica                  1041634
# 25744                   NaN  ...  MIDDLE VILLAGE                  1019086
# 25745              2 AVENUE  ...        BROOKLYN                   986087
# 25746                   NaN  ...   STATEN ISLAND                   937509
#
#       y_coordinate_state_plane            latitude           longitude  \
# 0                          NaN                 NaN                 NaN
# 1                       170855  40.635596930697716  -74.09243785251621
# 2                          NaN                 NaN                 NaN
# 3                          NaN                 NaN                 NaN
# 4                          NaN                 NaN                 NaN
# ...                        ...                 ...                 ...
# 25742                   149333  40.576529751013474  -74.08418458891498
# 25743                   183601   40.67043310054083  -73.79313890742239
# 25744                   202652   40.72284104810696  -73.87432253616811
# 25745                   184324   40.67260335878416  -73.99337766904543
# 25746                   172008   40.63867549665482  -74.16841436143491
#
#                                                 location  \
# 0                                                    NaN
# 1      {'latitude': '40.635596930697716', 'longitude'...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 25742  {'latitude': '40.576529751013474', 'longitude'...
# 25743  {'latitude': '40.67043310054083', 'longitude':...
# 25744  {'latitude': '40.72284104810696', 'longitude':...
# 25745  {'latitude': '40.67260335878416', 'longitude':...
# 25746  {'latitude': '40.63867549665482', 'longitude':...
#
#             incident_address       street_name         bbl due_date
# 0                        NaN               NaN         NaN      NaN
# 1                        NaN               NaN         NaN      NaN
# 2                        NaN               NaN         NaN      NaN
# 3           EAST  106 STREET  EAST  106 STREET         NaN      NaN
# 4                        NaN               NaN         NaN      NaN
# ...                      ...               ...         ...      ...
# 25742      753 QUINCY AVENUE     QUINCY AVENUE  5038260015      NaN
# 25743      145-33 130 AVENUE        130 AVENUE  4120710063      NaN
# 25744  62-82 DRY HARBOR ROAD   DRY HARBOR ROAD  4029690030      NaN
# 25745                    NaN               NaN         NaN      NaN
# 25746         6 BAILEY PLACE      BAILEY PLACE  5012720340      NaN
#
# [25747 rows x 32 columns]

# %%
# sanity checks
print(f'Number of total records: {results_df.shape[0]:,}.\n')
      
print('Min date:', results_df['created_date'].min())
print('Max date:', results_df['created_date'].max())
# Out:
# Number of total records: 25,747.
#
# Min date: 2010-01-02T08:26:00.000
# Max date: 2019-12-31T22:42:00.000

# %%
# summary of dataframe
results_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25747 entries, 0 to 25746
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   unique_key                      25747 non-null  object
#  1   created_date                    25747 non-null  object
#  2   closed_date                     25746 non-null  object
#  3   agency                          25747 non-null  object
#  4   agency_name                     25747 non-null  object
#  5   complaint_type                  25747 non-null  object
#  6   descriptor                      25747 non-null  object
#  7   cross_street_1                  22472 non-null  object
#  8   cross_street_2                  22464 non-null  object
#  9   intersection_street_1           9616 non-null   object
#  10  intersection_street_2           9616 non-null   object
#  11  address_type                    25741 non-null  object
#  12  facility_type                   23290 non-null  object
#  13  status                          25747 non-null  object
#  14  resolution_description          25743 non-null  object
#  15  resolution_action_updated_date  25747 non-null  object
#  16  community_board                 25747 non-null  object
#  17  borough                         25747 non-null  object
#  18  open_data_channel_type          25747 non-null  object
#  19  park_facility_name              25747 non-null  object
#  20  park_borough                    25747 non-null  object
#  21  incident_zip                    24899 non-null  object
#  22  city                            24901 non-null  object
#  23  x_coordinate_state_plane        24817 non-null  object
#  24  y_coordinate_state_plane        24817 non-null  object
#  25  latitude                        24817 non-null  object
#  26  longitude                       24817 non-null  object
#  27  location                        24817 non-null  object
#  28  incident_address                16188 non-null  object
#  29  street_name                     16188 non-null  object
#  30  bbl                             14603 non-null  object
#  31  due_date                        1 non-null      object
# dtypes: object(32)
# memory usage: 6.3+ MB

# %%
# sort count nulls descending per column
(results_df
 .isnull()
 .sum()
 .sort_values(ascending=False)
)
# Out:
# due_date                          25746
# intersection_street_1             16131
# intersection_street_2             16131
# bbl                               11144
# incident_address                   9559
# street_name                        9559
# cross_street_2                     3283
# cross_street_1                     3275
# facility_type                      2457
# latitude                            930
# location                            930
# x_coordinate_state_plane            930
# y_coordinate_state_plane            930
# longitude                           930
# incident_zip                        848
# city                                846
# address_type                          6
# resolution_description                4
# closed_date                           1
# park_borough                          0
# unique_key                            0
# park_facility_name                    0
# open_data_channel_type                0
# borough                               0
# created_date                          0
# resolution_action_updated_date        0
# status                                0
# descriptor                            0
# complaint_type                        0
# agency_name                           0
# agency                                0
# community_board                       0
# dtype: int64

# %% [markdown]
# # Write Out Data

# %%
# writing output file as a csv
outpath = '../data/street-flooding-complaints.csv'
results_df.to_csv(outpath, index=False)

# sanity check, list items in data folder
# %ls ../data/
# Out:
# README.md                               streets-clipped.gpkg
# street-flooding-complaints-cleaned.csv  streets.gpkg
# street-flooding-complaints.csv          water-main-break-raw.csv
# street-flooding-raw.csv                 water-main-breaks.csv

# %% [markdown]
# Sanity Check of CSV.

# %%
path = '../data/street-flooding-complaints.csv'
df = pd.read_csv(path, low_memory=False)

print(f'shape of data: {df.shape}')
df.head()
# Out:
# shape of data: (25747, 32)
#    unique_key             created_date              closed_date agency  \
# 0    18265181  2010-07-14T08:38:00.000  2010-07-14T08:38:00.000    DEP
# 1    34783066  2016-11-15T09:27:00.000  2016-11-15T10:05:00.000    DEP
# 2    21549616  2011-09-29T10:34:00.000  2011-09-30T10:40:00.000    DEP
# 3    35839080  2017-03-31T20:24:00.000  2017-04-01T02:25:00.000    DEP
# 4    29443390  2014-12-06T10:23:00.000  2014-12-06T11:30:00.000    DEP
#
#                               agency_name complaint_type  \
# 0  Department of Environmental Protection          Sewer
# 1  Department of Environmental Protection          Sewer
# 2  Department of Environmental Protection          Sewer
# 3  Department of Environmental Protection          Sewer
# 4  Department of Environmental Protection          Sewer
#
#              descriptor cross_street_1 cross_street_2 intersection_street_1  \
# 0  Street Flooding (SJ)    PELHAM PKWY  STILLWELL AVE           PELHAM PKWY
# 1  Street Flooding (SJ)            NaN            NaN      LAFAYETTE AVENUE
# 2  Street Flooding (SJ)            NaN            NaN           THURSBY AVE
# 3  Street Flooding (SJ)       3 AVENUE       2 AVENUE                   NaN
# 4  Street Flooding (SJ)      NAGLE AVE     DYCKMAN ST             NAGLE AVE
#
#    ...           city x_coordinate_state_plane  y_coordinate_state_plane  \
# 0  ...            NaN                      NaN                       NaN
# 1  ...  STATEN ISLAND                 958594.0                  170855.0
# 2  ...            NaN                      NaN                       NaN
# 3  ...       NEW YORK                      NaN                       NaN
# 4  ...            NaN                      NaN                       NaN
#
#     latitude  longitude                                           location  \
# 0        NaN        NaN                                                NaN
# 1  40.635597 -74.092438  {'latitude': '40.635596930697716', 'longitude'...
# 2        NaN        NaN                                                NaN
# 3        NaN        NaN                                                NaN
# 4        NaN        NaN                                                NaN
#
#    incident_address       street_name bbl due_date
# 0               NaN               NaN NaN      NaN
# 1               NaN               NaN NaN      NaN
# 2               NaN               NaN NaN      NaN
# 3  EAST  106 STREET  EAST  106 STREET NaN      NaN
# 4               NaN               NaN NaN      NaN
#
# [5 rows x 32 columns]

# %%
# summary of columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25747 entries, 0 to 25746
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   unique_key                      25747 non-null  int64
#  1   created_date                    25747 non-null  object
#  2   closed_date                     25746 non-null  object
#  3   agency                          25747 non-null  object
#  4   agency_name                     25747 non-null  object
#  5   complaint_type                  25747 non-null  object
#  6   descriptor                      25747 non-null  object
#  7   cross_street_1                  22472 non-null  object
#  8   cross_street_2                  22464 non-null  object
#  9   intersection_street_1           9616 non-null   object
#  10  intersection_street_2           9616 non-null   object
#  11  address_type                    25741 non-null  object
#  12  facility_type                   0 non-null      float64
#  13  status                          25747 non-null  object
#  14  resolution_description          25743 non-null  object
#  15  resolution_action_updated_date  25747 non-null  object
#  16  community_board                 25747 non-null  object
#  17  borough                         25747 non-null  object
#  18  open_data_channel_type          25747 non-null  object
#  19  park_facility_name              25747 non-null  object
#  20  park_borough                    25747 non-null  object
#  21  incident_zip                    24899 non-null  float64
#  22  city                            24901 non-null  object
#  23  x_coordinate_state_plane        24817 non-null  float64
#  24  y_coordinate_state_plane        24817 non-null  float64
#  25  latitude                        24817 non-null  float64
#  26  longitude                       24817 non-null  float64
#  27  location                        24817 non-null  object
#  28  incident_address                16188 non-null  object
#  29  street_name                     16188 non-null  object
#  30  bbl                             14603 non-null  float64
#  31  due_date                        1 non-null      object
# dtypes: float64(7), int64(1), object(24)
# memory usage: 6.3+ MB

# %% [markdown]
# There are two columns that we should probably drop due to percentage of missing data, `facility_type` and `due_date`. We will dive in further in the data inspection notebook.

# %% [markdown]
# # Work in Progress
# ## Water Main Breaks in 311 Complaints
# Understand the extent to which Water Main Break complaints are in the Street Flooding Complaints data and possibly filter out of this analysis. We may use this for later. For now, we'll at least write out this data.

# %%
query = """
    SELECT 
        descriptor, 
        count(descriptor) AS count
    WHERE 
        LOWER(descriptor) LIKE '%water main break%' 
    GROUP BY 
        descriptor  
    ORDER BY 
        count(descriptor) DESC
    LIMIT
        20 
"""

results = client.get(socrata_dataset_identifier, query=query)
results_df = pd.DataFrame(results)

print(f'shape of data: {results_df.shape}')
results_df
# Out:
# shape of data: (1, 2)
#                                        descriptor  count
# 0  Possible Water Main Break (Use Comments) (WA1)  42043

# %%
query = """
    SELECT 
        *
    WHERE 
        descriptor == 'Possible Water Main Break (Use Comments) (WA1)'
        AND created_date BETWEEN '2010' AND '2020'
    LIMIT
        100000 -- assign a large number
"""

results = client.get(socrata_dataset_identifier, query=query)
results_df = pd.DataFrame(results)

print(f'shape of data: {results_df.shape}')
results_df.head()
# Out:
# shape of data: (22631, 32)
#   unique_key             created_date              closed_date agency  \
# 0   21347159  2011-09-01T08:34:00.000  2011-09-09T08:00:00.000    DEP
# 1   32951975  2016-03-21T14:56:00.000  2016-03-21T14:56:00.000    DEP
# 2   36947802  2017-08-14T09:51:00.000  2017-08-14T14:30:00.000    DEP
# 3   37999718  2017-12-22T04:01:00.000  2017-12-22T14:30:00.000    DEP
# 4   33478457  2016-05-31T14:24:00.000  2016-05-31T17:00:00.000    DEP
#
#                               agency_name complaint_type  \
# 0  Department of Environmental Protection   Water System
# 1  Department of Environmental Protection   Water System
# 2  Department of Environmental Protection   Water System
# 3  Department of Environmental Protection   Water System
# 4  Department of Environmental Protection   Water System
#
#                                        descriptor intersection_street_1  \
# 0  Possible Water Main Break (Use Comments) (WA1)         ROCKAWAY BLVD
# 1  Possible Water Main Break (Use Comments) (WA1)         PARKVILLE AVE
# 2  Possible Water Main Break (Use Comments) (WA1)                   NaN
# 3  Possible Water Main Break (Use Comments) (WA1)                 68 ST
# 4  Possible Water Main Break (Use Comments) (WA1)                   NaN
#
#   intersection_street_2  address_type  ...       street_name incident_zip  \
# 0       BROOKVILLE BLVD  INTERSECTION  ...               NaN          NaN
# 1                E 8 ST  INTERSECTION  ...               NaN          NaN
# 2                   NaN  INTERSECTION  ...        EDISON AVE          NaN
# 3          WOODSIDE AVE  INTERSECTION  ...               NaN          NaN
# 4                   NaN       ADDRESS  ...  EAST  161 STREET        10456
#
#     city         bbl x_coordinate_state_plane y_coordinate_state_plane  \
# 0    NaN         NaN                      NaN                      NaN
# 1    NaN         NaN                      NaN                      NaN
# 2    NaN         NaN                      NaN                      NaN
# 3    NaN         NaN                      NaN                      NaN
# 4  BRONX  2026270001                  1009687                   238808
#
#             latitude           longitude  \
# 0                NaN                 NaN
# 1                NaN                 NaN
# 2                NaN                 NaN
# 3                NaN                 NaN
# 4  40.82211177009745  -73.90809432309149
#
#                                             location due_date
# 0                                                NaN      NaN
# 1                                                NaN      NaN
# 2                                                NaN      NaN
# 3                                                NaN      NaN
# 4  {'latitude': '40.82211177009745', 'longitude':...      NaN
#
# [5 rows x 32 columns]

# %%
# sanity checks
print(f'Number of total records: {results_df.shape[0]:,}.\n')
      
print('Min date:', results_df['created_date'].min())
print('Max date:', results_df['created_date'].max())
# Out:
# Number of total records: 22,631.
#
# Min date: 2010-01-01T06:28:00.000
# Max date: 2019-12-31T20:54:00.000

# %%
# summary of dataframe
results_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22631 entries, 0 to 22630
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   unique_key                      22631 non-null  object
#  1   created_date                    22631 non-null  object
#  2   closed_date                     22630 non-null  object
#  3   agency                          22631 non-null  object
#  4   agency_name                     22631 non-null  object
#  5   complaint_type                  22631 non-null  object
#  6   descriptor                      22631 non-null  object
#  7   intersection_street_1           7445 non-null   object
#  8   intersection_street_2           7445 non-null   object
#  9   address_type                    22627 non-null  object
#  10  facility_type                   21112 non-null  object
#  11  status                          22631 non-null  object
#  12  resolution_description          22630 non-null  object
#  13  resolution_action_updated_date  22631 non-null  object
#  14  community_board                 22631 non-null  object
#  15  borough                         22631 non-null  object
#  16  open_data_channel_type          22631 non-null  object
#  17  park_facility_name              22631 non-null  object
#  18  park_borough                    22631 non-null  object
#  19  cross_street_1                  19863 non-null  object
#  20  cross_street_2                  19829 non-null  object
#  21  incident_address                15249 non-null  object
#  22  street_name                     15249 non-null  object
#  23  incident_zip                    22055 non-null  object
#  24  city                            22058 non-null  object
#  25  bbl                             13420 non-null  object
#  26  x_coordinate_state_plane        21965 non-null  object
#  27  y_coordinate_state_plane        21965 non-null  object
#  28  latitude                        21965 non-null  object
#  29  longitude                       21965 non-null  object
#  30  location                        21965 non-null  object
#  31  due_date                        20 non-null     object
# dtypes: object(32)
# memory usage: 5.5+ MB

# %%
# writing output file as a csv
outpath = '../data/water-main-breaks.csv'
results_df.to_csv(outpath, index=False)

# sanity check, list items in data folder
# %ls ../data/
# Out:
# README.md                               streets-clipped.gpkg
# street-flooding-complaints-cleaned.csv  streets.gpkg
# street-flooding-complaints.csv          water-main-break-raw.csv
# street-flooding-raw.csv                 water-main-breaks.csv

# %%
# close sodapy client
client.close()
