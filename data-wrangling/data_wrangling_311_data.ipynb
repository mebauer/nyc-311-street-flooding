# %%
# importing libraries
import pandas as pd
import numpy as np
from sodapy import Socrata
import os

# %%
socrata_domain = 'data.cityofnewyork.us'
socrata_dataset_identifier = 'erm2-nwe9'

# If you choose to use a token, run the following command on the terminal (or add it to your .bashrc)
# $ export SODAPY_APPTOKEN=<token>
socrata_token = os.environ.get("SODAPY_APPTOKEN")

# %%
client = Socrata(socrata_domain, socrata_token)

# %%
metadata = client.get_metadata(socrata_dataset_identifier)
[x['name'] for x in metadata['columns']]
# Out:
# ['Unique Key',
#  'Created Date',
#  'Closed Date',
#  'Agency',
#  'Agency Name',
#  'Complaint Type',
#  'Descriptor',
#  'Location Type',
#  'Incident Zip',
#  'Incident Address',
#  'Street Name',
#  'Cross Street 1',
#  'Cross Street 2',
#  'Intersection Street 1',
#  'Intersection Street 2',
#  'Address Type',
#  'City',
#  'Landmark',
#  'Facility Type',
#  'Status',
#  'Due Date',
#  'Resolution Description',
#  'Resolution Action Updated Date',
#  'Community Board',
#  'BBL',
#  'Borough',
#  'X Coordinate (State Plane)',
#  'Y Coordinate (State Plane)',
#  'Open Data Channel Type',
#  'Park Facility Name',
#  'Park Borough',
#  'Vehicle Type',
#  'Taxi Company Borough',
#  'Taxi Pick Up Location',
#  'Bridge Highway Name',
#  'Bridge Highway Direction',
#  'Road Ramp',
#  'Bridge Highway Segment',
#  'Latitude',
#  'Longitude',
#  'Location',
#  'Zip Codes',
#  'Community Districts',
#  'Borough Boundaries',
#  'City Council Districts',
#  'Police Precincts']

# %%
meta_amount = [x for x in metadata['columns'] if x['name'] == 'Complaint Type'][0]
meta_amount
# Out:
# {'id': 354922035,
#  'name': 'Complaint Type',
#  'dataTypeName': 'text',
#  'description': 'This is the first level of a hierarchy identifying the topic of the incident or condition. Complaint Type may have a corresponding Descriptor (below) or may stand alone.',
#  'fieldName': 'complaint_type',
#  'position': 6,
#  'renderTypeName': 'text',
#  'tableColumnId': 1567792,
#  'width': 268,
#  'cachedContents': {'largest': 'ZTESTINT',
#   'non_null': '25093886',
#   'null': '0',
#   'top': [{'item': 'Noise - Residential', 'count': '2272076'},
#    {'item': 'HEAT/HOT WATER', 'count': '1469657'},
#    {'item': 'Illegal Parking', 'count': '1154532'},
#    {'item': 'Blocked Driveway', 'count': '1063932'},
#    {'item': 'Street Condition', 'count': '1028708'},
#    {'item': 'Street Light Condition', 'count': '990689'},
#    {'item': 'HEATING', 'count': '887869'},
#    {'item': 'PLUMBING', 'count': '753700'},
#    {'item': 'Water System', 'count': '692428'},
#    {'item': 'Noise - Street/Sidewalk', 'count': '688245'},
#    {'item': 'General Construction/Plumbing', 'count': '533673'},
#    {'item': 'Noise', 'count': '527716'},
#    {'item': 'UNSANITARY CONDITION', 'count': '520038'},
#    {'item': 'GENERAL CONSTRUCTION', 'count': '500863'},
#    {'item': 'Traffic Signal Condition', 'count': '473611'},
#    {'item': 'Noise - Commercial', 'count': '397728'},
#    {'item': 'Sewer', 'count': '386228'},
#    {'item': 'PAINT/PLASTER', 'count': '385567'},
#    {'item': 'Dirty Conditions', 'count': '376502'},
#    {'item': 'Damaged Tree', 'count': '365290'}],
#   'smallest': '../../../../../../../../../...',
#   'not_null': '21933957',
#   'cardinality': '445'},
#  'format': {'displayStyle': 'plain', 'align': 'left'}}

# %%
[x['fieldName'] for x in metadata['columns']]
# Out:
# ['unique_key',
#  'created_date',
#  'closed_date',
#  'agency',
#  'agency_name',
#  'complaint_type',
#  'descriptor',
#  'location_type',
#  'incident_zip',
#  'incident_address',
#  'street_name',
#  'cross_street_1',
#  'cross_street_2',
#  'intersection_street_1',
#  'intersection_street_2',
#  'address_type',
#  'city',
#  'landmark',
#  'facility_type',
#  'status',
#  'due_date',
#  'resolution_description',
#  'resolution_action_updated_date',
#  'community_board',
#  'bbl',
#  'borough',
#  'x_coordinate_state_plane',
#  'y_coordinate_state_plane',
#  'open_data_channel_type',
#  'park_facility_name',
#  'park_borough',
#  'vehicle_type',
#  'taxi_company_borough',
#  'taxi_pick_up_location',
#  'bridge_highway_name',
#  'bridge_highway_direction',
#  'road_ramp',
#  'bridge_highway_segment',
#  'latitude',
#  'longitude',
#  'location',
#  ':@computed_region_efsh_h5xi',
#  ':@computed_region_f5dn_yrer',
#  ':@computed_region_yeji_bk3q',
#  ':@computed_region_92fq_4b7q',
#  ':@computed_region_sbqj_enih']

# %%
# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofnewyork.us", socrata_token, timeout=1000)

query = """
SELECT 
    complaint_type, count(complaint_type)
GROUP BY 
    complaint_type
ORDER BY 
    count(complaint_type) DESC
LIMIT 
    1000000
"""

# Returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("erm2-nwe9", 
                     query=query)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)

print(results_df.shape)
results_df.head(10)
# Out:
# (445, 2)
#             complaint_type count_complaint_type
# 0      Noise - Residential              2272076
# 1           HEAT/HOT WATER              1469657
# 2          Illegal Parking              1154532
# 3         Blocked Driveway              1063932
# 4         Street Condition              1028708
# 5   Street Light Condition               990689
# 6                  HEATING               887869
# 7                 PLUMBING               753700
# 8             Water System               692428
# 9  Noise - Street/Sidewalk               688245

# %%
results_df.shape
# Out:
# (445, 2)

# %%
# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofnewyork.us", socrata_token, timeout=1000)

query = """
SELECT 
    descriptor, count(descriptor)
WHERE 
    LOWER(descriptor) LIKE '%flood%'
GROUP BY 
    descriptor
ORDER BY 
    count(descriptor) DESC
LIMIT 
    1000000
"""

# Returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("erm2-nwe9", 
                     query=query)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)

print(results_df.shape)
results_df
# Out:
# (11, 2)
#                                           descriptor count_descriptor
# 0   Catch Basin Clogged/Flooding (Use Comments) (SC)            90181
# 1                               Street Flooding (SJ)            27691
# 2                               Flood Light Lamp Out             5982
# 3                              Highway Flooding (SH)             2841
# 4                           Flood Light Lamp Cycling             2515
# 5                                Ready NY - Flooding              271
# 6                        Flood Light Lamp Dayburning              205
# 7                           Flood Light Lamp Missing              192
# 8                               Flood Light Lamp Dim              177
# 9                      RAIN GARDEN FLOODING (SRGFLD)               80
# 10                                           Flooded               48

# %%
# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofnewyork.us", socrata_token, timeout=1000)

query = """
SELECT 
    *
WHERE 
    LOWER(descriptor) LIKE '%flood%'
LIMIT 
    1000000
"""

# Returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("erm2-nwe9", 
                     query=query)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)

print(results_df.shape)
results_df.head()
# Out:
# (130183, 34)
#   unique_key             created_date              closed_date agency  \
# 0   35467474  2017-02-11T14:49:00.000  2017-02-17T11:19:00.000    DEP
# 1   35467500  2017-02-11T14:29:00.000  2017-02-16T13:15:00.000    DEP
# 2   35469916  2017-02-11T12:49:00.000  2017-02-27T09:35:00.000    DEP
# 3   35471209  2017-02-11T14:02:00.000  2017-02-23T08:20:00.000    DEP
# 4   35472529  2017-02-12T09:45:00.000  2017-02-14T10:50:00.000    DEP
#
#                               agency_name complaint_type  \
# 0  Department of Environmental Protection          Sewer
# 1  Department of Environmental Protection          Sewer
# 2  Department of Environmental Protection          Sewer
# 3  Department of Environmental Protection          Sewer
# 4  Department of Environmental Protection          Sewer
#
#                                          descriptor incident_zip  \
# 0                              Street Flooding (SJ)        10312
# 1  Catch Basin Clogged/Flooding (Use Comments) (SC)        11356
# 2  Catch Basin Clogged/Flooding (Use Comments) (SC)        10457
# 3  Catch Basin Clogged/Flooding (Use Comments) (SC)        11229
# 4  Catch Basin Clogged/Flooding (Use Comments) (SC)        11212
#
#           incident_address          street_name  ... park_facility_name  \
# 0       152 BARCLAY AVENUE       BARCLAY AVENUE  ...        Unspecified
# 1                      NaN                  NaN  ...        Unspecified
# 2  200 EAST TREMONT AVENUE  EAST TREMONT AVENUE  ...        Unspecified
# 3                      NaN                  NaN  ...        Unspecified
# 4        369 REMSEN AVENUE        REMSEN AVENUE  ...        Unspecified
#
#     park_borough            latitude           longitude  \
# 0  STATEN ISLAND   40.53905963837945  -74.17485518222908
# 1         QUEENS  40.780148506856214  -73.84694563006549
# 2          BRONX   40.84910933998956  -73.90541479343653
# 3       BROOKLYN  40.601296137704665  -73.95494277882723
# 4       BROOKLYN  40.656400699016416  -73.92397160612046
#
#                                             location intersection_street_1  \
# 0  {'latitude': '40.53905963837945', 'longitude':...                   NaN
# 1  {'latitude': '40.780148506856214', 'longitude'...             22 AVENUE
# 2  {'latitude': '40.84910933998956', 'longitude':...                   NaN
# 3  {'latitude': '40.601296137704665', 'longitude'...        EAST 17 STREET
# 4  {'latitude': '40.656400699016416', 'longitude'...                   NaN
#
#   intersection_street_2 location_type due_date landmark
# 0                   NaN           NaN      NaN      NaN
# 1            121 STREET           NaN      NaN      NaN
# 2                   NaN           NaN      NaN      NaN
# 3              AVENUE T           NaN      NaN      NaN
# 4                   NaN           NaN      NaN      NaN
#
# [5 rows x 34 columns]

# %%
results_df['descriptor'].value_counts()
# Out:
# Catch Basin Clogged/Flooding (Use Comments) (SC)    90181
# Street Flooding (SJ)                                27691
# Flood Light Lamp Out                                 5982
# Highway Flooding (SH)                                2841
# Flood Light Lamp Cycling                             2515
# Ready NY - Flooding                                   271
# Flood Light Lamp Dayburning                           205
# Flood Light Lamp Missing                              192
# Flood Light Lamp Dim                                  177
# RAIN GARDEN FLOODING (SRGFLD)                          80
# Flooded                                                48
# Name: descriptor, dtype: int64

# %%
results_df = results_df.loc[results_df['descriptor'] == 'Street Flooding (SJ)']

# %%
results_df['descriptor'].value_counts()
# Out:
# Street Flooding (SJ)    27691
# Name: descriptor, dtype: int64

# %%
results_df['complaint_type'].value_counts()
# Out:
# Sewer    27691
# Name: complaint_type, dtype: int64

# %%
results_df.shape
# Out:
# (27691, 34)

# %%
results_df.head()
# Out:
#    unique_key             created_date              closed_date agency  \
# 0    35467474  2017-02-11T14:49:00.000  2017-02-17T11:19:00.000    DEP
# 11   35473543  2017-02-12T19:03:00.000  2017-02-12T19:03:00.000    DEP
# 19   35475940  2017-02-12T14:38:00.000  2017-02-12T15:20:00.000    DEP
# 23   35478538  2017-02-13T13:11:00.000  2017-02-15T09:30:00.000    DEP
# 25   35479396  2017-02-13T07:26:00.000  2017-02-13T08:10:00.000    DEP
#
#                                agency_name complaint_type  \
# 0   Department of Environmental Protection          Sewer
# 11  Department of Environmental Protection          Sewer
# 19  Department of Environmental Protection          Sewer
# 23  Department of Environmental Protection          Sewer
# 25  Department of Environmental Protection          Sewer
#
#               descriptor incident_zip       incident_address  \
# 0   Street Flooding (SJ)        10312     152 BARCLAY AVENUE
# 11  Street Flooding (SJ)        11231                    NaN
# 19  Street Flooding (SJ)        10465    659 CLARENCE AVENUE
# 23  Street Flooding (SJ)        11210                    NaN
# 25  Street Flooding (SJ)        10466  1635 EAST  233 STREET
#
#          street_name  ... park_facility_name   park_borough  \
# 0     BARCLAY AVENUE  ...        Unspecified  STATEN ISLAND
# 11               NaN  ...        Unspecified       BROOKLYN
# 19   CLARENCE AVENUE  ...        Unspecified          BRONX
# 23               NaN  ...        Unspecified       BROOKLYN
# 25  EAST  233 STREET  ...        Unspecified          BRONX
#
#              latitude           longitude  \
# 0   40.53905963837945  -74.17485518222908
# 11  40.67694549612395   -73.9918702620602
# 19  40.82869324687791  -73.81430221749874
# 23  40.61981574824473  -73.94359080313858
# 25  40.88818786782963  -73.82690286717639
#
#                                              location intersection_street_1  \
# 0   {'latitude': '40.53905963837945', 'longitude':...                   NaN
# 11  {'latitude': '40.67694549612395', 'longitude':...              3 STREET
# 19  {'latitude': '40.82869324687791', 'longitude':...                   NaN
# 23  {'latitude': '40.61981574824473', 'longitude':...        EAST 32 STREET
# 25  {'latitude': '40.88818786782963', 'longitude':...                   NaN
#
#    intersection_street_2 location_type due_date landmark
# 0                    NaN           NaN      NaN      NaN
# 11           BOND STREET           NaN      NaN      NaN
# 19                   NaN           NaN      NaN      NaN
# 23              AVENUE M           NaN      NaN      NaN
# 25                   NaN           NaN      NaN      NaN
#
# [5 rows x 34 columns]

# %% [markdown]
# # Deleting records greater than year 2020

# %%
print('Number of total records:', len(results_df))
      
print('Min:', results_df.created_date.min())

print('Max:', results_df.created_date.max())
# Out:
# Number of total records: 27691
# Min: 2010-01-02T08:26:00.000
# Max: 2021-03-08T18:49:00.000

# %%
results_df.loc[results_df.created_date < '2021'].sort_values(by='created_date', ascending=False).head()
# Out:
#       unique_key             created_date              closed_date agency  \
# 43318   48542220  2020-12-31T15:41:00.000  2021-01-01T00:20:00.000    DEP
# 47881   48536430  2020-12-31T14:49:00.000  2021-01-04T10:15:00.000    DEP
# 57635   48539361  2020-12-31T14:03:00.000  2021-01-02T11:25:00.000    DEP
# 57638   48543132  2020-12-31T13:48:00.000  2020-12-31T14:50:00.000    DEP
# 55929   48536441  2020-12-31T13:10:00.000  2021-01-03T10:45:00.000    DEP
#
#                                   agency_name complaint_type  \
# 43318  Department of Environmental Protection          Sewer
# 47881  Department of Environmental Protection          Sewer
# 57635  Department of Environmental Protection          Sewer
# 57638  Department of Environmental Protection          Sewer
# 55929  Department of Environmental Protection          Sewer
#
#                  descriptor incident_zip      incident_address  \
# 43318  Street Flooding (SJ)        11420     117-17 135 STREET
# 47881  Street Flooding (SJ)        11357      20-24 150 STREET
# 57635  Street Flooding (SJ)        11228         7223 8 AVENUE
# 57638  Street Flooding (SJ)        10032                   NaN
# 55929  Street Flooding (SJ)        11234  3123 FILLMORE AVENUE
#
#            street_name  ... park_facility_name park_borough  \
# 43318       135 STREET  ...        Unspecified       QUEENS
# 47881       150 STREET  ...        Unspecified       QUEENS
# 57635         8 AVENUE  ...        Unspecified     BROOKLYN
# 57638              NaN  ...        Unspecified    MANHATTAN
# 55929  FILLMORE AVENUE  ...        Unspecified     BROOKLYN
#
#                  latitude           longitude  \
# 43318   40.67703755925495  -73.80441718054371
# 47881   40.78072630540092  -73.81428794578581
# 57635   40.62849640806448  -74.01680967626773
# 57638  40.841051689545516   -73.9446789892306
# 55929  40.609203447399906  -73.93654793950026
#
#                                                 location  \
# 43318  {'latitude': '40.67703755925495', 'longitude':...
# 47881  {'latitude': '40.78072630540092', 'longitude':...
# 57635  {'latitude': '40.62849640806448', 'longitude':...
# 57638  {'latitude': '40.841051689545516', 'longitude'...
# 55929  {'latitude': '40.609203447399906', 'longitude'...
#
#       intersection_street_1 intersection_street_2 location_type due_date  \
# 43318                   NaN                   NaN           NaN      NaN
# 47881                   NaN                   NaN           NaN      NaN
# 57635                   NaN                   NaN           NaN      NaN
# 57638       RIVERSIDE DRIVE       WEST 165 STREET           NaN      NaN
# 55929                   NaN                   NaN           NaN      NaN
#
#       landmark
# 43318      NaN
# 47881      NaN
# 57635      NaN
# 57638      NaN
# 55929      NaN
#
# [5 rows x 34 columns]

# %%
results_df = results_df.loc[results_df.created_date < '2021']

print(len(results_df))

print('Min:', results_df.created_date.min())

print('Max:', results_df.created_date.max())
# Out:
# 27428
# Min: 2010-01-02T08:26:00.000
# Max: 2020-12-31T15:41:00.000

# %%
# writing output file as a csv
results_df.to_csv('../data-raw/raw_street_flooding_complaints.csv', index=False)

# listing items in data folder
# %ls ../data-raw/
# Out:
# README.md                           raw_street_flooding_complaints.csv
# data-dictionaries/                  raw_streets_clipped.json

# %% [markdown]
# # Briefly reviewing what descriptors are in the complaint_type='Sewer'

# %%
# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofnewyork.us", socrata_token, timeout=1000)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofnewyork.us,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

query = """
SELECT 
    descriptor, count(descriptor)
WHERE 
    complaint_type='Sewer'
GROUP BY 
    descriptor
ORDER BY 
    count(descriptor) DESC
"""

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("erm2-nwe9", 
                     query=query)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)

print(results_df.shape)
results_df.head(len(results_df))
# Out:
# (27, 2)
#                                            descriptor count_descriptor
# 0                    Sewer Backup (Use Comments) (SA)           149981
# 1    Catch Basin Clogged/Flooding (Use Comments) (SC)            90181
# 2             Catch Basin Sunken/Damaged/Raised (SC1)            28632
# 3                                Street Flooding (SJ)            27691
# 4              Manhole Cover Broken/Making Noise (SB)            19780
# 5             Manhole Cover Missing (Emergency) (SA3)            17649
# 6                                    Sewer Odor (SA2)            15453
# 7                  Defective/Missing Curb Piece (SC4)             8526
# 8               Manhole Overflow (Use Comments) (SA1)             6928
# 9                            Catch Basin Search (SC2)             4154
# 10                  Catch Basin Grating Missing (SA4)             3777
# 11                Manhole Sunken/Damaged/Raised (SB1)             3450
# 12                              Highway Flooding (SH)             2841
# 13                Culvert Blocked/Needs Cleaning (SE)             2228
# 14           Other Sewer Problem (Use Comments) (SZZ)             1329
# 15                                  Sewer Break (SBR)             1034
# 16                    Plate Noisy/Sunken/Raised (SB5)              875
# 17            Plate Missing/Moved-Exposing Hole (SB4)              645
# 18                        RAIN GARDEN DEBRIS (SRGDBR)              377
# 19                   Street Cave-In / Depression (SG)              302
# 20                                      Trench (SZZ1)              192
# 21                      RAIN GARDEN FLOODING (SRGFLD)               80
# 22                   DAMAGE STRUCTURE/RAILING (SRGDM)               51
# 23  Recurring after SOAP *FOR DEP INTERNAL USE ONL...               29
# 24       Street Cave-In *Dep Internal Use Only* (SG1)               27
# 25  Catch Basin Connection Broken *Dep Internal Us...               15
# 26  SOAP segment *FOR DEP INTERNAL USE ONLY* (SOAP...                1
