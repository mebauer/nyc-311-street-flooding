# %%
# importing libraries
import pandas as pd
import numpy as np
from sodapy import Socrata
import os

# %%
socrata_domain = 'data.cityofnewyork.us'
socrata_dataset_identifier = 'erm2-nwe9'

# If you choose to use a token, run the following command on the terminal (or add it to your .bashrc)
# $ export SODAPY_APPTOKEN=<token>
socrata_token = os.environ.get("SODAPY_APPTOKEN")

# %%
client = Socrata(socrata_domain, socrata_token)

# %%
metadata = client.get_metadata(socrata_dataset_identifier)
[x['name'] for x in metadata['columns']]
# Out:
# ['Unique Key',
#  'Created Date',
#  'Closed Date',
#  'Agency',
#  'Agency Name',
#  'Complaint Type',
#  'Descriptor',
#  'Location Type',
#  'Incident Zip',
#  'Incident Address',
#  'Street Name',
#  'Cross Street 1',
#  'Cross Street 2',
#  'Intersection Street 1',
#  'Intersection Street 2',
#  'Address Type',
#  'City',
#  'Landmark',
#  'Facility Type',
#  'Status',
#  'Due Date',
#  'Resolution Description',
#  'Resolution Action Updated Date',
#  'Community Board',
#  'BBL',
#  'Borough',
#  'X Coordinate (State Plane)',
#  'Y Coordinate (State Plane)',
#  'Open Data Channel Type',
#  'Park Facility Name',
#  'Park Borough',
#  'Vehicle Type',
#  'Taxi Company Borough',
#  'Taxi Pick Up Location',
#  'Bridge Highway Name',
#  'Bridge Highway Direction',
#  'Road Ramp',
#  'Bridge Highway Segment',
#  'Latitude',
#  'Longitude',
#  'Location',
#  'Zip Codes',
#  'Community Districts',
#  'Borough Boundaries',
#  'City Council Districts',
#  'Police Precincts']

# %%
meta_amount = [x for x in metadata['columns'] if x['name'] == 'Complaint Type'][0]
meta_amount
# Out:
# {'id': 354922035,
#  'name': 'Complaint Type',
#  'dataTypeName': 'text',
#  'description': 'This is the first level of a hierarchy identifying the topic of the incident or condition. Complaint Type may have a corresponding Descriptor (below) or may stand alone.',
#  'fieldName': 'complaint_type',
#  'position': 6,
#  'renderTypeName': 'text',
#  'tableColumnId': 1567792,
#  'width': 268,
#  'cachedContents': {'largest': 'ZTESTINT',
#   'non_null': '25644113',
#   'null': '0',
#   'top': [{'item': 'Noise - Residential', 'count': '2225885'},
#    {'item': 'HEAT/HOT WATER', 'count': '1407396'},
#    {'item': 'Illegal Parking', 'count': '1117015'},
#    {'item': 'Blocked Driveway', 'count': '1041075'},
#    {'item': 'Street Condition', 'count': '1018764'},
#    {'item': 'Street Light Condition', 'count': '981297'},
#    {'item': 'HEATING', 'count': '887869'},
#    {'item': 'PLUMBING', 'count': '744723'},
#    {'item': 'Water System', 'count': '698995'},
#    {'item': 'Noise - Street/Sidewalk', 'count': '680970'},
#    {'item': 'Noise', 'count': '577308'},
#    {'item': 'General Construction/Plumbing', 'count': '534056'},
#    {'item': 'UNSANITARY CONDITION', 'count': '507468'},
#    {'item': 'GENERAL CONSTRUCTION', 'count': '500863'},
#    {'item': 'Traffic Signal Condition', 'count': '467532'},
#    {'item': 'Noise - Commercial', 'count': '393773'},
#    {'item': 'Sewer', 'count': '386577'},
#    {'item': 'PAINT/PLASTER', 'count': '375248'},
#    {'item': 'Dirty Conditions', 'count': '375115'},
#    {'item': 'Damaged Tree', 'count': '363849'}],
#   'smallest': '../../../../../../../../../...',
#   'not_null': '21933957',
#   'cardinality': '499'},
#  'format': {'displayStyle': 'plain', 'align': 'left'}}

# %%
[x['fieldName'] for x in metadata['columns']]
# Out:
# ['unique_key',
#  'created_date',
#  'closed_date',
#  'agency',
#  'agency_name',
#  'complaint_type',
#  'descriptor',
#  'location_type',
#  'incident_zip',
#  'incident_address',
#  'street_name',
#  'cross_street_1',
#  'cross_street_2',
#  'intersection_street_1',
#  'intersection_street_2',
#  'address_type',
#  'city',
#  'landmark',
#  'facility_type',
#  'status',
#  'due_date',
#  'resolution_description',
#  'resolution_action_updated_date',
#  'community_board',
#  'bbl',
#  'borough',
#  'x_coordinate_state_plane',
#  'y_coordinate_state_plane',
#  'open_data_channel_type',
#  'park_facility_name',
#  'park_borough',
#  'vehicle_type',
#  'taxi_company_borough',
#  'taxi_pick_up_location',
#  'bridge_highway_name',
#  'bridge_highway_direction',
#  'road_ramp',
#  'bridge_highway_segment',
#  'latitude',
#  'longitude',
#  'location',
#  ':@computed_region_efsh_h5xi',
#  ':@computed_region_f5dn_yrer',
#  ':@computed_region_yeji_bk3q',
#  ':@computed_region_92fq_4b7q',
#  ':@computed_region_sbqj_enih']

# %%
# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofnewyork.us", socrata_token, timeout=1000)

query = """
SELECT 
    complaint_type, count(complaint_type)
GROUP BY 
    complaint_type
ORDER BY 
    count(complaint_type) DESC
LIMIT 
    1000000
"""

# Returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("erm2-nwe9", 
                     query=query)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)

print(results_df.shape)
results_df.head(10)
# Out:
# (499, 2)
#             complaint_type count_complaint_type
# 0      Noise - Residential              2225885
# 1           HEAT/HOT WATER              1407396
# 2          Illegal Parking              1117015
# 3         Blocked Driveway              1041075
# 4         Street Condition              1018764
# 5   Street Light Condition               981297
# 6                  HEATING               887869
# 7                 PLUMBING               744723
# 8             Water System               698995
# 9  Noise - Street/Sidewalk               680970

# %%
results_df.shape
# Out:
# (499, 2)

# %%
# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofnewyork.us", socrata_token, timeout=1000)

query = """
SELECT 
    descriptor, count(descriptor)
WHERE 
    LOWER(descriptor) LIKE '%flood%'
GROUP BY 
    descriptor
ORDER BY 
    count(descriptor) DESC
LIMIT 
    1000000
"""

# Returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("erm2-nwe9", 
                     query=query)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)

print(results_df.shape)
results_df
# Out:
# (13, 2)
#                                           descriptor count_descriptor
# 0   Catch Basin Clogged/Flooding (Use Comments) (SC)            90647
# 1                               Street Flooding (SJ)            27906
# 2                               Flood Light Lamp Out             5954
# 3                                 Flooding on Street             3175
# 4                              Highway Flooding (SH)             2839
# 5                           Flood Light Lamp Cycling             2510
# 6                                Ready NY - Flooding              271
# 7                        Flood Light Lamp Dayburning              205
# 8                           Flood Light Lamp Missing              190
# 9                               Flood Light Lamp Dim              177
# 10                     RAIN GARDEN FLOODING (SRGFLD)               85
# 11                               Flooding on Highway               76
# 12                                           Flooded               48

# %%
# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofnewyork.us", socrata_token, timeout=1000)

query = """
SELECT 
    *
WHERE 
    LOWER(descriptor) LIKE '%flood%'
LIMIT 
    1000000
"""

# Returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("erm2-nwe9", 
                     query=query)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)

print(results_df.shape)
results_df.head()
# Out:
# (134083, 38)
#   unique_key             created_date              closed_date agency  \
# 0   24860647  2013-01-25T08:42:00.000  2013-01-28T09:20:00.000    DEP
# 1   24883645  2013-01-28T15:42:00.000  2013-01-30T09:00:00.000    DEP
# 2   24892185  2013-01-29T09:45:00.000  2013-03-11T09:20:00.000    DOT
# 3   24897032  2013-01-29T09:19:00.000  2013-01-29T14:38:00.000    DOT
# 4   24912103  2013-01-31T16:20:00.000  2013-02-01T11:27:00.000    DOT
#
#                               agency_name          complaint_type  \
# 0  Department of Environmental Protection                   Sewer
# 1  Department of Environmental Protection                   Sewer
# 2            Department of Transportation  Street Light Condition
# 3            Department of Transportation  Street Light Condition
# 4            Department of Transportation  Street Light Condition
#
#                                          descriptor incident_zip  \
# 0  Catch Basin Clogged/Flooding (Use Comments) (SC)        11694
# 1  Catch Basin Clogged/Flooding (Use Comments) (SC)        11201
# 2                          Flood Light Lamp Cycling        11211
# 3                          Flood Light Lamp Cycling        11215
# 4                          Flood Light Lamp Cycling        11213
#
#             incident_address                street_name  ...  \
# 0           BEACH 128 STREET           BEACH 128 STREET  ...
# 1  FLATBUSH AVENUE EXTENSION  FLATBUSH AVENUE EXTENSION  ...
# 2                        NaN                        NaN  ...
# 3                 1108 8 AVE                      8 AVE  ...
# 4              176 UTICA AVE                  UTICA AVE  ...
#
#   intersection_street_1 intersection_street_2  bbl location_type due_date  \
# 0                   NaN                   NaN  NaN           NaN      NaN
# 1                   NaN                   NaN  NaN           NaN      NaN
# 2          GRAND STREET    VANDERVOORT AVENUE  NaN           NaN      NaN
# 3              8 AVENUE             12 STREET  NaN           NaN      NaN
# 4          UTICA AVENUE            PARK PLACE  NaN           NaN      NaN
#
#   landmark bridge_highway_name bridge_highway_direction road_ramp  \
# 0      NaN                 NaN                      NaN       NaN
# 1      NaN                 NaN                      NaN       NaN
# 2      NaN                 NaN                      NaN       NaN
# 3      NaN                 NaN                      NaN       NaN
# 4      NaN                 NaN                      NaN       NaN
#
#   bridge_highway_segment
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
#
# [5 rows x 38 columns]

# %%
results_df['descriptor'].value_counts()
# Out:
# Catch Basin Clogged/Flooding (Use Comments) (SC)    90647
# Street Flooding (SJ)                                27906
# Flood Light Lamp Out                                 5954
# Flooding on Street                                   3175
# Highway Flooding (SH)                                2839
# Flood Light Lamp Cycling                             2510
# Ready NY - Flooding                                   271
# Flood Light Lamp Dayburning                           205
# Flood Light Lamp Missing                              190
# Flood Light Lamp Dim                                  177
# RAIN GARDEN FLOODING (SRGFLD)                          85
# Flooding on Highway                                    76
# Flooded                                                48
# Name: descriptor, dtype: int64

# %%
results_df = results_df[results_df['descriptor'] == 'Street Flooding (SJ)']

# %%
results_df['descriptor'].value_counts()
# Out:
# Street Flooding (SJ)    27906
# Name: descriptor, dtype: int64

# %%
results_df['complaint_type'].value_counts()
# Out:
# Sewer    27906
# Name: complaint_type, dtype: int64

# %%
results_df.shape
# Out:
# (27906, 38)

# %%
results_df.head()
# Out:
#     unique_key             created_date              closed_date agency  \
# 38    31862075  2015-10-28T17:44:00.000  2015-10-29T11:30:00.000    DEP
# 48    25163797  2013-03-12T12:38:00.000  2013-03-12T14:20:00.000    DEP
# 53    25185984  2013-03-15T12:13:00.000  2013-03-18T14:15:00.000    DEP
# 54    25187738  2013-03-15T12:20:00.000  2013-03-15T14:22:00.000    DEP
# 107   25338491  2013-04-11T12:16:00.000  2013-04-11T12:16:00.000    DEP
#
#                                 agency_name complaint_type  \
# 38   Department of Environmental Protection          Sewer
# 48   Department of Environmental Protection          Sewer
# 53   Department of Environmental Protection          Sewer
# 54   Department of Environmental Protection          Sewer
# 107  Department of Environmental Protection          Sewer
#
#                descriptor incident_zip  incident_address       street_name  \
# 38   Street Flooding (SJ)        11694  BEACH 101 STREET  BEACH 101 STREET
# 48   Street Flooding (SJ)        11236       CHURCH LANE       CHURCH LANE
# 53   Street Flooding (SJ)        11236       CHURCH LANE       CHURCH LANE
# 54   Street Flooding (SJ)        11236       CHURCH LANE       CHURCH LANE
# 107  Street Flooding (SJ)        11236       CHURCH LANE       CHURCH LANE
#
#      ... intersection_street_1 intersection_street_2  bbl location_type  \
# 38   ...                   NaN                   NaN  NaN           NaN
# 48   ...                   NaN                   NaN  NaN           NaN
# 53   ...                   NaN                   NaN  NaN           NaN
# 54   ...                   NaN                   NaN  NaN           NaN
# 107  ...                   NaN                   NaN  NaN           NaN
#
#     due_date landmark bridge_highway_name bridge_highway_direction road_ramp  \
# 38       NaN      NaN                 NaN                      NaN       NaN
# 48       NaN      NaN                 NaN                      NaN       NaN
# 53       NaN      NaN                 NaN                      NaN       NaN
# 54       NaN      NaN                 NaN                      NaN       NaN
# 107      NaN      NaN                 NaN                      NaN       NaN
#
#     bridge_highway_segment
# 38                     NaN
# 48                     NaN
# 53                     NaN
# 54                     NaN
# 107                    NaN
#
# [5 rows x 38 columns]

# %% [markdown]
# # Deleting records greater than year 2020

# %%
print('Number of total records:', len(results_df))
      
print('Min:', results_df.created_date.min())

print('Max:', results_df.created_date.max())
# Out:
# Number of total records: 27906
# Min: 2010-01-02T08:26:00.000
# Max: 2021-01-08T18:50:00.000

# %%
results_df[results_df.created_date < '2021'].sort_values(by='created_date', ascending=False).head()
# Out:
#        unique_key             created_date              closed_date agency  \
# 119612   48542220  2020-12-31T15:41:00.000  2021-01-01T00:20:00.000    DEP
# 119567   48536430  2020-12-31T14:49:00.000  2021-01-04T10:15:00.000    DEP
# 119584   48539361  2020-12-31T14:03:00.000  2021-01-02T11:25:00.000    DEP
# 119629   48543132  2020-12-31T13:48:00.000  2020-12-31T14:50:00.000    DEP
# 119568   48536441  2020-12-31T13:10:00.000  2021-01-03T10:45:00.000    DEP
#
#                                    agency_name complaint_type  \
# 119612  Department of Environmental Protection          Sewer
# 119567  Department of Environmental Protection          Sewer
# 119584  Department of Environmental Protection          Sewer
# 119629  Department of Environmental Protection          Sewer
# 119568  Department of Environmental Protection          Sewer
#
#                   descriptor incident_zip      incident_address  \
# 119612  Street Flooding (SJ)        11420     117-17 135 STREET
# 119567  Street Flooding (SJ)        11357      20-24 150 STREET
# 119584  Street Flooding (SJ)        11228         7223 8 AVENUE
# 119629  Street Flooding (SJ)        10032                   NaN
# 119568  Street Flooding (SJ)        11234  3123 FILLMORE AVENUE
#
#             street_name  ... intersection_street_1 intersection_street_2  \
# 119612       135 STREET  ...                   NaN                   NaN
# 119567       150 STREET  ...                   NaN                   NaN
# 119584         8 AVENUE  ...                   NaN                   NaN
# 119629              NaN  ...       RIVERSIDE DRIVE       WEST 165 STREET
# 119568  FILLMORE AVENUE  ...                   NaN                   NaN
#
#                bbl location_type due_date landmark bridge_highway_name  \
# 119612  4116990057           NaN      NaN      NaN                 NaN
# 119567  4046700029           NaN      NaN      NaN                 NaN
# 119584  3059120001           NaN      NaN      NaN                 NaN
# 119629         NaN           NaN      NaN      NaN                 NaN
# 119568  3084750001           NaN      NaN      NaN                 NaN
#
#        bridge_highway_direction road_ramp bridge_highway_segment
# 119612                      NaN       NaN                    NaN
# 119567                      NaN       NaN                    NaN
# 119584                      NaN       NaN                    NaN
# 119629                      NaN       NaN                    NaN
# 119568                      NaN       NaN                    NaN
#
# [5 rows x 38 columns]

# %%
results_df = results_df[results_df.created_date < '2021']

print(len(results_df))

print('Min:', results_df.created_date.min())

print('Max:', results_df.created_date.max())
# Out:
# 27868
# min: 2010-01-02T08:26:00.000
# max: 2020-12-31T15:41:00.000

# %%
# writing output file as a csv
results_df.to_csv('../data-raw/raw-street-flooding-data.csv', index=False)

# listing items in data folder
# %ls ../data-raw/
# Out:
# raw-street-flooding-data.csv  raw-streets-clipped.json

# %% [markdown]
# # Briefly reviewing what descriptors are in the complaint_type='Sewer'

# %%
# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofnewyork.us", socrata_token, timeout=1000)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofnewyork.us,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

query = """
SELECT 
    descriptor, count(descriptor)
WHERE 
    complaint_type='Sewer'
GROUP BY 
    descriptor
ORDER BY 
    count(descriptor) DESC
"""

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("erm2-nwe9", 
                     query=query)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)

print(results_df.shape)
results_df.head(len(results_df))
# Out:
# (27, 2)
#                                            descriptor count_descriptor
# 0                    Sewer Backup (Use Comments) (SA)           149675
# 1    Catch Basin Clogged/Flooding (Use Comments) (SC)            90647
# 2             Catch Basin Sunken/Damaged/Raised (SC1)            28719
# 3                                Street Flooding (SJ)            27906
# 4              Manhole Cover Broken/Making Noise (SB)            19777
# 5             Manhole Cover Missing (Emergency) (SA3)            17566
# 6                                    Sewer Odor (SA2)            15453
# 7                  Defective/Missing Curb Piece (SC4)             8517
# 8               Manhole Overflow (Use Comments) (SA1)             6879
# 9                            Catch Basin Search (SC2)             4153
# 10                  Catch Basin Grating Missing (SA4)             3768
# 11                Manhole Sunken/Damaged/Raised (SB1)             3430
# 12                              Highway Flooding (SH)             2839
# 13                Culvert Blocked/Needs Cleaning (SE)             2258
# 14           Other Sewer Problem (Use Comments) (SZZ)             1336
# 15                                  Sewer Break (SBR)             1036
# 16                    Plate Noisy/Sunken/Raised (SB5)              874
# 17            Plate Missing/Moved-Exposing Hole (SB4)              645
# 18                        RAIN GARDEN DEBRIS (SRGDBR)              388
# 19                   Street Cave-In / Depression (SG)              302
# 20                                      Trench (SZZ1)              192
# 21                      RAIN GARDEN FLOODING (SRGFLD)               85
# 22                   DAMAGE STRUCTURE/RAILING (SRGDM)               56
# 23       Street Cave-In *Dep Internal Use Only* (SG1)               31
# 24  Recurring after SOAP *FOR DEP INTERNAL USE ONL...               29
# 25  Catch Basin Connection Broken *Dep Internal Us...               15
# 26  SOAP segment *FOR DEP INTERNAL USE ONLY* (SOAP...                1
